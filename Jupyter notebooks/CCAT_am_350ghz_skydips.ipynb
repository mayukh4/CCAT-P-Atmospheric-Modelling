# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as ss
plt.rcParams['axes.grid'] = True

# %% [markdown]
# ### Skydips at 350 GHz ( i.e from 330 GHz to 366 GHz with 10 MHz resolution, 36 GHz bandwidth ) set at 5.6 KMs
#
# #### power loading at the detectors and fractional frequency shifts as a function of elevation angle
#
# #### output:Z(km), ZA(deg), f(GHz), tau, tx, Trj(K), Tb(K)
#
# #### EA = 90 - ZA
#
# #### power at the detector = T_rj * k * bw(Hz)

# %%
# defining constants 

k = 1.38064e-23 #boltzman constant
bw = 36e9 #Hz
eff =0.3 # 30% detector efficiency

# %%
#------------------------------------------------------------------ loading data --------------------------------------------------------------


#------------------------------------------------------------------ANNUAL----------------------------------------------------------------

submm_load_CCAT_350ghz_annual_5 = np.loadtxt("submm_load_CCAT_350ghz_annual_5_skydip.out")
submm_load_CCAT_350ghz_annual_50 = np.loadtxt("submm_load_CCAT_350ghz_annual_50_skydip.out")
submm_load_CCAT_350ghz_annual_95 = np.loadtxt("submm_load_CCAT_350ghz_annual_95_skydip.out")

# extracting the parameters

ea_submm_load_CCAT_350ghz_annual_5 = 90-submm_load_CCAT_350ghz_annual_5[:,1]
f_submm_load_CCAT_350ghz_annual_5 = submm_load_CCAT_350ghz_annual_5[:,2]
tau_submm_load_CCAT_350ghz_annual_5 =submm_load_CCAT_350ghz_annual_5[:,3]
tx_submm_load_CCAT_350ghz_annual_5 =submm_load_CCAT_350ghz_annual_5[:,4]
trj_submm_load_CCAT_350ghz_annual_5 = submm_load_CCAT_350ghz_annual_5[:,5]
tb_submm_load_CCAT_350ghz_annual_5 = submm_load_CCAT_350ghz_annual_5[:,6]



ea_submm_load_CCAT_350ghz_annual_50 = 90-submm_load_CCAT_350ghz_annual_50[:,1]
f_submm_load_CCAT_350ghz_annual_50 = submm_load_CCAT_350ghz_annual_50[:,2]
tau_submm_load_CCAT_350ghz_annual_50 =submm_load_CCAT_350ghz_annual_50[:,3]
tx_submm_load_CCAT_350ghz_annual_50 =submm_load_CCAT_350ghz_annual_50[:,4]
trj_submm_load_CCAT_350ghz_annual_50 = submm_load_CCAT_350ghz_annual_50[:,5]
tb_submm_load_CCAT_350ghz_annual_50 = submm_load_CCAT_350ghz_annual_50[:,6]

ea_submm_load_CCAT_350ghz_annual_95 = 90-submm_load_CCAT_350ghz_annual_95[:,1]
f_submm_load_CCAT_350ghz_annual_95 = submm_load_CCAT_350ghz_annual_95[:,2]
tau_submm_load_CCAT_350ghz_annual_95 =submm_load_CCAT_350ghz_annual_95[:,3]
tx_submm_load_CCAT_350ghz_annual_95 =submm_load_CCAT_350ghz_annual_95[:,4]
trj_submm_load_CCAT_350ghz_annual_95 = submm_load_CCAT_350ghz_annual_95[:,5]
tb_submm_load_CCAT_350ghz_annual_95 = submm_load_CCAT_350ghz_annual_95[:,6]



#------------------------------------------------------------------DJF----------------------------------------------------------------

submm_load_CCAT_350ghz_DJF_5 = np.loadtxt("submm_load_CCAT_350ghz_DJF_5_skydip.out")
submm_load_CCAT_350ghz_DJF_50 = np.loadtxt("submm_load_CCAT_350ghz_DJF_50_skydip.out")
submm_load_CCAT_350ghz_DJF_95 = np.loadtxt("submm_load_CCAT_350ghz_DJF_95_skydip.out")

# extracting the parameters

ea_submm_load_CCAT_350ghz_DJF_5 = 90-submm_load_CCAT_350ghz_DJF_5[:,1]
f_submm_load_CCAT_350ghz_DJF_5 = submm_load_CCAT_350ghz_DJF_5[:,2]
tau_submm_load_CCAT_350ghz_DJF_5 =submm_load_CCAT_350ghz_DJF_5[:,3]
tx_submm_load_CCAT_350ghz_DJF_5 =submm_load_CCAT_350ghz_DJF_5[:,4]
trj_submm_load_CCAT_350ghz_DJF_5 = submm_load_CCAT_350ghz_DJF_5[:,5]
tb_submm_load_CCAT_350ghz_DJF_5 = submm_load_CCAT_350ghz_DJF_5[:,6]

ea_submm_load_CCAT_350ghz_DJF_50 = 90-submm_load_CCAT_350ghz_DJF_50[:,1]
f_submm_load_CCAT_350ghz_DJF_50 = submm_load_CCAT_350ghz_DJF_50[:,2]
tau_submm_load_CCAT_350ghz_DJF_50 =submm_load_CCAT_350ghz_DJF_50[:,3]
tx_submm_load_CCAT_350ghz_DJF_50 =submm_load_CCAT_350ghz_DJF_50[:,4]
trj_submm_load_CCAT_350ghz_DJF_50 = submm_load_CCAT_350ghz_DJF_50[:,5]
tb_submm_load_CCAT_350ghz_DJF_50 = submm_load_CCAT_350ghz_DJF_50[:,6]

ea_submm_load_CCAT_350ghz_DJF_95 = 90-submm_load_CCAT_350ghz_DJF_95[:,1]
f_submm_load_CCAT_350ghz_DJF_95 = submm_load_CCAT_350ghz_DJF_95[:,2]
tau_submm_load_CCAT_350ghz_DJF_95 =submm_load_CCAT_350ghz_DJF_95[:,3]
tx_submm_load_CCAT_350ghz_DJF_95 =submm_load_CCAT_350ghz_DJF_95[:,4]
trj_submm_load_CCAT_350ghz_DJF_95 = submm_load_CCAT_350ghz_DJF_95[:,5]
tb_submm_load_CCAT_350ghz_DJF_95 = submm_load_CCAT_350ghz_DJF_95[:,6]


#------------------------------------------------------------------JFM----------------------------------------------------------------

submm_load_CCAT_350ghz_JFM_5 = np.loadtxt("submm_load_CCAT_350ghz_JFM_5_skydip.out")
submm_load_CCAT_350ghz_JFM_50 = np.loadtxt("submm_load_CCAT_350ghz_JFM_50_skydip.out")
submm_load_CCAT_350ghz_JFM_95 = np.loadtxt("submm_load_CCAT_350ghz_JFM_95_skydip.out")

# extracting the parameters

ea_submm_load_CCAT_350ghz_JFM_5 = 90-submm_load_CCAT_350ghz_JFM_5[:,1]
f_submm_load_CCAT_350ghz_JFM_5 = submm_load_CCAT_350ghz_JFM_5[:,2]
tau_submm_load_CCAT_350ghz_JFM_5 =submm_load_CCAT_350ghz_JFM_5[:,3]
tx_submm_load_CCAT_350ghz_JFM_5 =submm_load_CCAT_350ghz_JFM_5[:,4]
trj_submm_load_CCAT_350ghz_JFM_5 = submm_load_CCAT_350ghz_JFM_5[:,5]
tb_submm_load_CCAT_350ghz_JFM_5 = submm_load_CCAT_350ghz_JFM_5[:,6]

ea_submm_load_CCAT_350ghz_JFM_50 = 90-submm_load_CCAT_350ghz_JFM_50[:,1]
f_submm_load_CCAT_350ghz_JFM_50 = submm_load_CCAT_350ghz_JFM_50[:,2]
tau_submm_load_CCAT_350ghz_JFM_50 =submm_load_CCAT_350ghz_JFM_50[:,3]
tx_submm_load_CCAT_350ghz_JFM_50 =submm_load_CCAT_350ghz_JFM_50[:,4]
trj_submm_load_CCAT_350ghz_JFM_50 = submm_load_CCAT_350ghz_JFM_50[:,5]
tb_submm_load_CCAT_350ghz_JFM_50 = submm_load_CCAT_350ghz_JFM_50[:,6]

ea_submm_load_CCAT_350ghz_JFM_95 = 90-submm_load_CCAT_350ghz_JFM_95[:,1]
f_submm_load_CCAT_350ghz_JFM_95 = submm_load_CCAT_350ghz_JFM_95[:,2]
tau_submm_load_CCAT_350ghz_JFM_95 =submm_load_CCAT_350ghz_JFM_95[:,3]
tx_submm_load_CCAT_350ghz_JFM_95 =submm_load_CCAT_350ghz_JFM_95[:,4]
trj_submm_load_CCAT_350ghz_JFM_95 = submm_load_CCAT_350ghz_JFM_95[:,5]
tb_submm_load_CCAT_350ghz_JFM_95 = submm_load_CCAT_350ghz_JFM_95[:,6]


#------------------------------------------------------------------MAM----------------------------------------------------------------

submm_load_CCAT_350ghz_MAM_5 = np.loadtxt("submm_load_CCAT_350ghz_MAM_5_skydip.out")
submm_load_CCAT_350ghz_MAM_50 = np.loadtxt("submm_load_CCAT_350ghz_MAM_50_skydip.out")
submm_load_CCAT_350ghz_MAM_95 = np.loadtxt("submm_load_CCAT_350ghz_MAM_95_skydip.out")

# extracting the parameters

ea_submm_load_CCAT_350ghz_MAM_5 = 90-submm_load_CCAT_350ghz_MAM_5[:,1]
f_submm_load_CCAT_350ghz_MAM_5 = submm_load_CCAT_350ghz_MAM_5[:,2]
tau_submm_load_CCAT_350ghz_MAM_5 =submm_load_CCAT_350ghz_MAM_5[:,3]
tx_submm_load_CCAT_350ghz_MAM_5 =submm_load_CCAT_350ghz_MAM_5[:,4]
trj_submm_load_CCAT_350ghz_MAM_5 = submm_load_CCAT_350ghz_MAM_5[:,5]
tb_submm_load_CCAT_350ghz_MAM_5 = submm_load_CCAT_350ghz_MAM_5[:,6]

ea_submm_load_CCAT_350ghz_MAM_50 = 90-submm_load_CCAT_350ghz_MAM_50[:,1]
f_submm_load_CCAT_350ghz_MAM_50 = submm_load_CCAT_350ghz_MAM_50[:,2]
tau_submm_load_CCAT_350ghz_MAM_50 =submm_load_CCAT_350ghz_MAM_50[:,3]
tx_submm_load_CCAT_350ghz_MAM_50 =submm_load_CCAT_350ghz_MAM_50[:,4]
trj_submm_load_CCAT_350ghz_MAM_50 = submm_load_CCAT_350ghz_MAM_50[:,5]
tb_submm_load_CCAT_350ghz_MAM_50 = submm_load_CCAT_350ghz_MAM_50[:,6]

ea_submm_load_CCAT_350ghz_MAM_95 = 90-submm_load_CCAT_350ghz_MAM_95[:,1]
f_submm_load_CCAT_350ghz_MAM_95 = submm_load_CCAT_350ghz_MAM_95[:,2]
tau_submm_load_CCAT_350ghz_MAM_95 =submm_load_CCAT_350ghz_MAM_95[:,3]
tx_submm_load_CCAT_350ghz_MAM_95 =submm_load_CCAT_350ghz_MAM_95[:,4]
trj_submm_load_CCAT_350ghz_MAM_95 = submm_load_CCAT_350ghz_MAM_95[:,5]
tb_submm_load_CCAT_350ghz_MAM_95 = submm_load_CCAT_350ghz_MAM_95[:,6]

#------------------------------------------------------------------JJA----------------------------------------------------------------

submm_load_CCAT_350ghz_JJA_5 = np.loadtxt("submm_load_CCAT_350ghz_JJA_5_skydip.out")
submm_load_CCAT_350ghz_JJA_50 = np.loadtxt("submm_load_CCAT_350ghz_JJA_50_skydip.out")
submm_load_CCAT_350ghz_JJA_95 = np.loadtxt("submm_load_CCAT_350ghz_JJA_95_skydip.out")

# extracting the parameters

ea_submm_load_CCAT_350ghz_JJA_5 = 90-submm_load_CCAT_350ghz_JJA_5[:,1]
f_submm_load_CCAT_350ghz_JJA_5 = submm_load_CCAT_350ghz_JJA_5[:,2]
tau_submm_load_CCAT_350ghz_JJA_5 =submm_load_CCAT_350ghz_JJA_5[:,3]
tx_submm_load_CCAT_350ghz_JJA_5 =submm_load_CCAT_350ghz_JJA_5[:,4]
trj_submm_load_CCAT_350ghz_JJA_5 = submm_load_CCAT_350ghz_JJA_5[:,5]
tb_submm_load_CCAT_350ghz_JJA_5 = submm_load_CCAT_350ghz_JJA_5[:,6]

ea_submm_load_CCAT_350ghz_JJA_50 = 90-submm_load_CCAT_350ghz_JJA_50[:,1]
f_submm_load_CCAT_350ghz_JJA_50 = submm_load_CCAT_350ghz_JJA_50[:,2]
tau_submm_load_CCAT_350ghz_JJA_50 =submm_load_CCAT_350ghz_JJA_50[:,3]
tx_submm_load_CCAT_350ghz_JJA_50 =submm_load_CCAT_350ghz_JJA_50[:,4]
trj_submm_load_CCAT_350ghz_JJA_50 = submm_load_CCAT_350ghz_JJA_50[:,5]
tb_submm_load_CCAT_350ghz_JJA_50 = submm_load_CCAT_350ghz_JJA_50[:,6]

ea_submm_load_CCAT_350ghz_JJA_95 = 90-submm_load_CCAT_350ghz_JJA_95[:,1]
f_submm_load_CCAT_350ghz_JJA_95 = submm_load_CCAT_350ghz_JJA_95[:,2]
tau_submm_load_CCAT_350ghz_JJA_95 =submm_load_CCAT_350ghz_JJA_95[:,3]
tx_submm_load_CCAT_350ghz_JJA_95 =submm_load_CCAT_350ghz_JJA_95[:,4]
trj_submm_load_CCAT_350ghz_JJA_95 = submm_load_CCAT_350ghz_JJA_95[:,5]
tb_submm_load_CCAT_350ghz_JJA_95 = submm_load_CCAT_350ghz_JJA_95[:,6]

#------------------------------------------------------------------SON----------------------------------------------------------------

submm_load_CCAT_350ghz_SON_5 = np.loadtxt("submm_load_CCAT_350ghz_SON_5_skydip.out")
submm_load_CCAT_350ghz_SON_50 = np.loadtxt("submm_load_CCAT_350ghz_SON_50_skydip.out")
submm_load_CCAT_350ghz_SON_95 = np.loadtxt("submm_load_CCAT_350ghz_SON_95_skydip.out")

# extracting the parameters

ea_submm_load_CCAT_350ghz_SON_5 = 90-submm_load_CCAT_350ghz_SON_5[:,1]
f_submm_load_CCAT_350ghz_SON_5 = submm_load_CCAT_350ghz_SON_5[:,2]
tau_submm_load_CCAT_350ghz_SON_5 =submm_load_CCAT_350ghz_SON_5[:,3]
tx_submm_load_CCAT_350ghz_SON_5 =submm_load_CCAT_350ghz_SON_5[:,4]
trj_submm_load_CCAT_350ghz_SON_5 = submm_load_CCAT_350ghz_SON_5[:,5]
tb_submm_load_CCAT_350ghz_SON_5 = submm_load_CCAT_350ghz_SON_5[:,6]

ea_submm_load_CCAT_350ghz_SON_50 = 90-submm_load_CCAT_350ghz_SON_50[:,1]
f_submm_load_CCAT_350ghz_SON_50 = submm_load_CCAT_350ghz_SON_50[:,2]
tau_submm_load_CCAT_350ghz_SON_50 =submm_load_CCAT_350ghz_SON_50[:,3]
tx_submm_load_CCAT_350ghz_SON_50 =submm_load_CCAT_350ghz_SON_50[:,4]
trj_submm_load_CCAT_350ghz_SON_50 = submm_load_CCAT_350ghz_SON_50[:,5]
tb_submm_load_CCAT_350ghz_SON_50 = submm_load_CCAT_350ghz_SON_50[:,6]

ea_submm_load_CCAT_350ghz_SON_95 = 90-submm_load_CCAT_350ghz_SON_95[:,1]
f_submm_load_CCAT_350ghz_SON_95 = submm_load_CCAT_350ghz_SON_95[:,2]
tau_submm_load_CCAT_350ghz_SON_95 =submm_load_CCAT_350ghz_SON_95[:,3]
tx_submm_load_CCAT_350ghz_SON_95 =submm_load_CCAT_350ghz_SON_95[:,4]
trj_submm_load_CCAT_350ghz_SON_95 = submm_load_CCAT_350ghz_SON_95[:,5]
tb_submm_load_CCAT_350ghz_SON_95 = submm_load_CCAT_350ghz_SON_95[:,6]

# %%
# power loading at the detectors in W

#-------------------------------------------------------------------------------------------ANNUAL-----------------------------------------------------------

pow_submm_load_CCAT_350ghz_annual_5 = eff * trj_submm_load_CCAT_350ghz_annual_5 * k * bw 
pow_submm_load_CCAT_350ghz_annual_50 = eff * trj_submm_load_CCAT_350ghz_annual_50 * k * bw 
pow_submm_load_CCAT_350ghz_annual_95 = eff * trj_submm_load_CCAT_350ghz_annual_95 * k * bw 

#------------------------------------------------------------------------------------------DJF----------------------------------------------------------------
pow_submm_load_CCAT_350ghz_DJF_5 = eff * trj_submm_load_CCAT_350ghz_DJF_5 * k * bw 
pow_submm_load_CCAT_350ghz_DJF_50 = eff * trj_submm_load_CCAT_350ghz_DJF_50 * k * bw 
pow_submm_load_CCAT_350ghz_DJF_95 = eff * trj_submm_load_CCAT_350ghz_DJF_95 * k * bw 

#------------------------------------------------------------------------------------------JFM----------------------------------------------------------------
pow_submm_load_CCAT_350ghz_JFM_5 = eff * trj_submm_load_CCAT_350ghz_JFM_5 * k * bw 
pow_submm_load_CCAT_350ghz_JFM_50 = eff * trj_submm_load_CCAT_350ghz_JFM_50 * k * bw 
pow_submm_load_CCAT_350ghz_JFM_95 = eff * trj_submm_load_CCAT_350ghz_JFM_95 * k * bw 

#------------------------------------------------------------------------------------------MAM----------------------------------------------------------------
pow_submm_load_CCAT_350ghz_MAM_5 = eff * trj_submm_load_CCAT_350ghz_MAM_5 * k * bw 
pow_submm_load_CCAT_350ghz_MAM_50 = eff * trj_submm_load_CCAT_350ghz_MAM_50 * k * bw 
pow_submm_load_CCAT_350ghz_MAM_95 = eff * trj_submm_load_CCAT_350ghz_MAM_95 * k * bw 

#------------------------------------------------------------------------------------------JJA----------------------------------------------------------------
pow_submm_load_CCAT_350ghz_JJA_5 = eff * trj_submm_load_CCAT_350ghz_JJA_5 * k * bw 
pow_submm_load_CCAT_350ghz_JJA_50 = eff * trj_submm_load_CCAT_350ghz_JJA_50 * k * bw 
pow_submm_load_CCAT_350ghz_JJA_95 = eff * trj_submm_load_CCAT_350ghz_JJA_95 * k * bw 

#------------------------------------------------------------------------------------------SON----------------------------------------------------------------
pow_submm_load_CCAT_350ghz_SON_5 = eff * trj_submm_load_CCAT_350ghz_SON_5 * k * bw 
pow_submm_load_CCAT_350ghz_SON_50 = eff * trj_submm_load_CCAT_350ghz_SON_50 * k * bw 
pow_submm_load_CCAT_350ghz_SON_95 = eff * trj_submm_load_CCAT_350ghz_SON_95 * k * bw

# %%
fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("350 GHz Atmospheric Opacity vs Elevation Angle (Alt= 5.6 Km| BW= 36 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_5,tau_submm_load_CCAT_350ghz_annual_5 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_50,tau_submm_load_CCAT_350ghz_annual_50 ,label ="$H_2O$: 50th percentile")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_95,tau_submm_load_CCAT_350ghz_annual_95 ,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_5,tau_submm_load_CCAT_350ghz_DJF_5 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_50,tau_submm_load_CCAT_350ghz_DJF_50 ,label ="$H_2O$: 50th percentile")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_95,tau_submm_load_CCAT_350ghz_DJF_95 ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_5,tau_submm_load_CCAT_350ghz_JFM_5 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_50,tau_submm_load_CCAT_350ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_95,tau_submm_load_CCAT_350ghz_JFM_95 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_5,tau_submm_load_CCAT_350ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_50,tau_submm_load_CCAT_350ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_95,tau_submm_load_CCAT_350ghz_MAM_95 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_5,tau_submm_load_CCAT_350ghz_JJA_5 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_50,tau_submm_load_CCAT_350ghz_JJA_50 ,label ="$H_2O$: 50th percentile")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_95,tau_submm_load_CCAT_350ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_5,tau_submm_load_CCAT_350ghz_SON_5 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_50,tau_submm_load_CCAT_350ghz_SON_50 ,label ="$H_2O$: 50th percentile")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_95,tau_submm_load_CCAT_350ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading tauer (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, 'Atmospheric Opacity', va='center', rotation='vertical',size=14)


plt.savefig("350ghz_outputs/350 GHz Atmospheric Opacity vs Elevation Angle (Alt= 5.6 Km| BW= 36 GHz)_V1.jpg",dpi="figure")

plt.show()

# %%
c_350ghz_annual_5, b_350ghz_annual_5= np.histogram(tau_submm_load_CCAT_350ghz_annual_5)
pdf_350ghz_annual_5 = c_350ghz_annual_5 / sum(c_350ghz_annual_5)
cdf_350ghz_annual_5 = np.cumsum(pdf_350ghz_annual_5)
plt.plot(cdf_350ghz_annual_5)

# %%
# calculating the cumulative fraction as a fuction of the optical depth/opacity tau

#-------------------------------------------------------------------------------------------ANNUAL-----------------------------------------------------------

data_submm_load_CCAT_350ghz_annual_5 = tau_submm_load_CCAT_350ghz_annual_5
data_sorted_submm_load_CCAT_350ghz_annual_5 = np.sort(data_submm_load_CCAT_350ghz_annual_5)
p_submm_load_CCAT_350ghz_annual_5 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_annual_5)) / (len(data_submm_load_CCAT_350ghz_annual_5) - 1)

data_submm_load_CCAT_350ghz_annual_50 = tau_submm_load_CCAT_350ghz_annual_50
data_sorted_submm_load_CCAT_350ghz_annual_50 = np.sort(data_submm_load_CCAT_350ghz_annual_50)
p_submm_load_CCAT_350ghz_annual_50 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_annual_50)) / (len(data_submm_load_CCAT_350ghz_annual_50) - 1)

data_submm_load_CCAT_350ghz_annual_95 = tau_submm_load_CCAT_350ghz_annual_95
data_sorted_submm_load_CCAT_350ghz_annual_95 = np.sort(data_submm_load_CCAT_350ghz_annual_95)
p_submm_load_CCAT_350ghz_annual_95 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_annual_95)) / (len(data_submm_load_CCAT_350ghz_annual_95) - 1)

# calculating the cumulative fraction as a fuction of the optical depth/opacity tau

#-------------------------------------------------------------------------------------------DJF-----------------------------------------------------------

data_submm_load_CCAT_350ghz_DJF_5 = tau_submm_load_CCAT_350ghz_DJF_5
data_sorted_submm_load_CCAT_350ghz_DJF_5 = np.sort(data_submm_load_CCAT_350ghz_DJF_5)
p_submm_load_CCAT_350ghz_DJF_5 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_DJF_5)) / (len(data_submm_load_CCAT_350ghz_DJF_5) - 1)

data_submm_load_CCAT_350ghz_DJF_50 = tau_submm_load_CCAT_350ghz_DJF_50
data_sorted_submm_load_CCAT_350ghz_DJF_50 = np.sort(data_submm_load_CCAT_350ghz_DJF_50)
p_submm_load_CCAT_350ghz_DJF_50 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_DJF_50)) / (len(data_submm_load_CCAT_350ghz_DJF_50) - 1)

data_submm_load_CCAT_350ghz_DJF_95 = tau_submm_load_CCAT_350ghz_DJF_95
data_sorted_submm_load_CCAT_350ghz_DJF_95 = np.sort(data_submm_load_CCAT_350ghz_DJF_95)
p_submm_load_CCAT_350ghz_DJF_95 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_DJF_95)) / (len(data_submm_load_CCAT_350ghz_DJF_95) - 1)

# calculating the cumulative fraction as a fuction of the optical depth/opacity tau
#-------------------------------------------------------------------------------------------JFM-----------------------------------------------------------

data_submm_load_CCAT_350ghz_JFM_5 = tau_submm_load_CCAT_350ghz_JFM_5
data_sorted_submm_load_CCAT_350ghz_JFM_5 = np.sort(data_submm_load_CCAT_350ghz_JFM_5)
p_submm_load_CCAT_350ghz_JFM_5 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_JFM_5)) / (len(data_submm_load_CCAT_350ghz_JFM_5) - 1)

data_submm_load_CCAT_350ghz_JFM_50 = tau_submm_load_CCAT_350ghz_JFM_50
data_sorted_submm_load_CCAT_350ghz_JFM_50 = np.sort(data_submm_load_CCAT_350ghz_JFM_50)
p_submm_load_CCAT_350ghz_JFM_50 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_JFM_50)) / (len(data_submm_load_CCAT_350ghz_JFM_50) - 1)

data_submm_load_CCAT_350ghz_JFM_95 = tau_submm_load_CCAT_350ghz_JFM_95
data_sorted_submm_load_CCAT_350ghz_JFM_95 = np.sort(data_submm_load_CCAT_350ghz_JFM_95)
p_submm_load_CCAT_350ghz_JFM_95 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_JFM_95)) / (len(data_submm_load_CCAT_350ghz_JFM_95) - 1)

# calculating the cumulative fraction as a fuction of the optical depth/opacity tau
#-------------------------------------------------------------------------------------------MAM-----------------------------------------------------------

data_submm_load_CCAT_350ghz_MAM_5 = tau_submm_load_CCAT_350ghz_MAM_5
data_sorted_submm_load_CCAT_350ghz_MAM_5 = np.sort(data_submm_load_CCAT_350ghz_MAM_5)
p_submm_load_CCAT_350ghz_MAM_5 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_MAM_5)) / (len(data_submm_load_CCAT_350ghz_MAM_5) - 1)

data_submm_load_CCAT_350ghz_MAM_50 = tau_submm_load_CCAT_350ghz_MAM_50
data_sorted_submm_load_CCAT_350ghz_MAM_50 = np.sort(data_submm_load_CCAT_350ghz_MAM_50)
p_submm_load_CCAT_350ghz_MAM_50 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_MAM_50)) / (len(data_submm_load_CCAT_350ghz_MAM_50) - 1)

data_submm_load_CCAT_350ghz_MAM_95 = tau_submm_load_CCAT_350ghz_MAM_95
data_sorted_submm_load_CCAT_350ghz_MAM_95 = np.sort(data_submm_load_CCAT_350ghz_MAM_95)
p_submm_load_CCAT_350ghz_MAM_95 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_MAM_95)) / (len(data_submm_load_CCAT_350ghz_MAM_95) - 1)

# calculating the cumulative fraction as a fuction of the optical depth/opacity tau
#-------------------------------------------------------------------------------------------JJA-----------------------------------------------------------

data_submm_load_CCAT_350ghz_JJA_5 = tau_submm_load_CCAT_350ghz_JJA_5
data_sorted_submm_load_CCAT_350ghz_JJA_5 = np.sort(data_submm_load_CCAT_350ghz_JJA_5)
p_submm_load_CCAT_350ghz_JJA_5 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_JJA_5)) / (len(data_submm_load_CCAT_350ghz_JJA_5) - 1)

data_submm_load_CCAT_350ghz_JJA_50 = tau_submm_load_CCAT_350ghz_JJA_50
data_sorted_submm_load_CCAT_350ghz_JJA_50 = np.sort(data_submm_load_CCAT_350ghz_JJA_50)
p_submm_load_CCAT_350ghz_JJA_50 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_JJA_50)) / (len(data_submm_load_CCAT_350ghz_JJA_50) - 1)

data_submm_load_CCAT_350ghz_JJA_95 = tau_submm_load_CCAT_350ghz_JJA_95
data_sorted_submm_load_CCAT_350ghz_JJA_95 = np.sort(data_submm_load_CCAT_350ghz_JJA_95)
p_submm_load_CCAT_350ghz_JJA_95 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_JJA_95)) / (len(data_submm_load_CCAT_350ghz_JJA_95) - 1)

# calculating the cumulative fraction as a fuction of the optical depth/opacity tau
#-------------------------------------------------------------------------------------------SON-----------------------------------------------------------

data_submm_load_CCAT_350ghz_SON_5 = tau_submm_load_CCAT_350ghz_SON_5
data_sorted_submm_load_CCAT_350ghz_SON_5 = np.sort(data_submm_load_CCAT_350ghz_SON_5)
p_submm_load_CCAT_350ghz_SON_5 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_SON_5)) / (len(data_submm_load_CCAT_350ghz_SON_5) - 1)

data_submm_load_CCAT_350ghz_SON_50 = tau_submm_load_CCAT_350ghz_SON_50
data_sorted_submm_load_CCAT_350ghz_SON_50 = np.sort(data_submm_load_CCAT_350ghz_SON_50)
p_submm_load_CCAT_350ghz_SON_50 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_SON_50)) / (len(data_submm_load_CCAT_350ghz_SON_50) - 1)

data_submm_load_CCAT_350ghz_SON_95 = tau_submm_load_CCAT_350ghz_SON_95
data_sorted_submm_load_CCAT_350ghz_SON_95 = np.sort(data_submm_load_CCAT_350ghz_SON_95)
p_submm_load_CCAT_350ghz_SON_95 = 1. * np.arange(len(data_submm_load_CCAT_350ghz_SON_95)) / (len(data_submm_load_CCAT_350ghz_SON_95) - 1)

# %%
fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("350 GHz Cumulative distributions of zenith optical depths (Alt= 5.6 Km| BW= 36 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(data_sorted_submm_load_CCAT_350ghz_annual_5,p_submm_load_CCAT_350ghz_annual_5 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(data_sorted_submm_load_CCAT_350ghz_annual_50,p_submm_load_CCAT_350ghz_annual_50 ,label ="$H_2O$: 50th percentile")
axs[0][0].plot(data_sorted_submm_load_CCAT_350ghz_annual_95,p_submm_load_CCAT_350ghz_annual_95 ,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(data_sorted_submm_load_CCAT_350ghz_DJF_5,p_submm_load_CCAT_350ghz_DJF_5 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(data_sorted_submm_load_CCAT_350ghz_DJF_50,p_submm_load_CCAT_350ghz_DJF_50 ,label="$H_2O$: 50th percentile")
axs[0][1].plot(data_sorted_submm_load_CCAT_350ghz_DJF_95,p_submm_load_CCAT_350ghz_DJF_95 ,label="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(data_sorted_submm_load_CCAT_350ghz_JFM_5,p_submm_load_CCAT_350ghz_JFM_5 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(data_sorted_submm_load_CCAT_350ghz_JFM_50,p_submm_load_CCAT_350ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
axs[0][2].plot(data_sorted_submm_load_CCAT_350ghz_JFM_95,p_submm_load_CCAT_350ghz_JFM_95 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(data_sorted_submm_load_CCAT_350ghz_MAM_5,p_submm_load_CCAT_350ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(data_sorted_submm_load_CCAT_350ghz_MAM_50,p_submm_load_CCAT_350ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
axs[1][0].plot(data_sorted_submm_load_CCAT_350ghz_MAM_95,p_submm_load_CCAT_350ghz_MAM_95 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(data_sorted_submm_load_CCAT_350ghz_JJA_5,p_submm_load_CCAT_350ghz_JJA_5 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(data_sorted_submm_load_CCAT_350ghz_JJA_50,p_submm_load_CCAT_350ghz_JJA_50 ,label ="$H_2O$: 50th percentile")
axs[1][1].plot(data_sorted_submm_load_CCAT_350ghz_JJA_95,p_submm_load_CCAT_350ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(data_sorted_submm_load_CCAT_350ghz_SON_5,p_submm_load_CCAT_350ghz_SON_5 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(data_sorted_submm_load_CCAT_350ghz_SON_50,p_submm_load_CCAT_350ghz_SON_50 ,label ="$H_2O$: 50th percentile")
axs[1][2].plot(data_sorted_submm_load_CCAT_350ghz_SON_95,p_submm_load_CCAT_350ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading txer (pW) ",size=12)

fig.text(0.5, 0.04, r'Opacity ($ \tau $)', ha='center',size=15)
fig.text(0.07, 0.5, 'Cumulative Fraction', va='center', rotation='vertical',size=14)

plt.savefig("350ghz_outputs/350 GHz Cumulative distributions of zenith optical depths (Alt= 5.6 Km| BW= 36 GHz)_V1.jpg",dpi="figure")


plt.savefig("350ghz_outputs/350 GHz Cumulative distributions of zenith optical depths (Alt= 5.6 Km| BW= 36 GHz)_V1.jpg",dpi="figure")

plt.show()

# %%
# calculating the cumulative fraction as a fuction of the optical depth/opacity tau

#-------------------------------------------------------------------------------------------ANNUAL-----------------------------------------------------------

c_350ghz_annual_5, b_350ghz_annual_5= np.histogram(tau_submm_load_CCAT_350ghz_annual_5)
pdf_350ghz_annual_5 = c_350ghz_annual_5 / sum(c_350ghz_annual_5)
cdf_350ghz_annual_5 = np.cumsum(pdf_350ghz_annual_5)


c_350ghz_annual_50, b_350ghz_annual_50= np.histogram(tau_submm_load_CCAT_350ghz_annual_50)
pdf_350ghz_annual_50 = c_350ghz_annual_50 / sum(c_350ghz_annual_50)
cdf_350ghz_annual_50 = np.cumsum(pdf_350ghz_annual_50)

c_350ghz_annual_95, b_350ghz_annual_95= np.histogram(tau_submm_load_CCAT_350ghz_annual_95)
pdf_350ghz_annual_95 = c_350ghz_annual_95 / sum(c_350ghz_annual_95)
cdf_350ghz_annual_95 = np.cumsum(pdf_350ghz_annual_95)

#-------------------------------------------------------------------------------------------DJF-----------------------------------------------------------

c_350ghz_DJF_5, b_350ghz_DJF_5= np.histogram(tau_submm_load_CCAT_350ghz_DJF_5)
pdf_350ghz_DJF_5 = c_350ghz_DJF_5 / sum(c_350ghz_DJF_5)
cdf_350ghz_DJF_5 = np.cumsum(pdf_350ghz_DJF_5)
#plt.plot(cdf_350ghz_DJF_5)

c_350ghz_DJF_50, b_350ghz_DJF_50= np.histogram(tau_submm_load_CCAT_350ghz_DJF_50)
pdf_350ghz_DJF_50 = c_350ghz_DJF_50 / sum(c_350ghz_DJF_50)
cdf_350ghz_DJF_50 = np.cumsum(pdf_350ghz_DJF_50)

c_350ghz_DJF_95, b_350ghz_DJF_95= np.histogram(tau_submm_load_CCAT_350ghz_DJF_95)
pdf_350ghz_DJF_95 = c_350ghz_DJF_95 / sum(c_350ghz_DJF_95)
cdf_350ghz_DJF_95 = np.cumsum(pdf_350ghz_DJF_95)

#-------------------------------------------------------------------------------------------JFM-----------------------------------------------------------

c_350ghz_JFM_5, b_350ghz_JFM_5= np.histogram(tau_submm_load_CCAT_350ghz_JFM_5)
pdf_350ghz_JFM_5 = c_350ghz_JFM_5 / sum(c_350ghz_JFM_5)
cdf_350ghz_JFM_5 = np.cumsum(pdf_350ghz_JFM_5)
#plt.plot(cdf_350ghz_JFM_5)

c_350ghz_JFM_50, b_350ghz_JFM_50= np.histogram(tau_submm_load_CCAT_350ghz_JFM_50)
pdf_350ghz_JFM_50 = c_350ghz_JFM_50 / sum(c_350ghz_JFM_50)
cdf_350ghz_JFM_50 = np.cumsum(pdf_350ghz_JFM_50)

c_350ghz_JFM_95, b_350ghz_JFM_95= np.histogram(tau_submm_load_CCAT_350ghz_JFM_95)
pdf_350ghz_JFM_95 = c_350ghz_JFM_95 / sum(c_350ghz_JFM_95)
cdf_350ghz_JFM_95 = np.cumsum(pdf_350ghz_JFM_95)

#-------------------------------------------------------------------------------------------MAM-----------------------------------------------------------

c_350ghz_MAM_5, b_350ghz_MAM_5= np.histogram(tau_submm_load_CCAT_350ghz_MAM_5)
pdf_350ghz_MAM_5 = c_350ghz_MAM_5 / sum(c_350ghz_MAM_5)
cdf_350ghz_MAM_5 = np.cumsum(pdf_350ghz_MAM_5)
#plt.plot(cdf_350ghz_MAM_5)

c_350ghz_MAM_50, b_350ghz_MAM_50= np.histogram(tau_submm_load_CCAT_350ghz_MAM_50)
pdf_350ghz_MAM_50 = c_350ghz_MAM_50 / sum(c_350ghz_MAM_50)
cdf_350ghz_MAM_50 = np.cumsum(pdf_350ghz_MAM_50)

c_350ghz_MAM_95, b_350ghz_MAM_95= np.histogram(tau_submm_load_CCAT_350ghz_MAM_95)
pdf_350ghz_MAM_95 = c_350ghz_MAM_95 / sum(c_350ghz_MAM_95)
cdf_350ghz_MAM_95 = np.cumsum(pdf_350ghz_MAM_95)

#-------------------------------------------------------------------------------------------JJA-----------------------------------------------------------

c_350ghz_JJA_5, b_350ghz_JJA_5= np.histogram(tau_submm_load_CCAT_350ghz_JJA_5)
pdf_350ghz_JJA_5 = c_350ghz_JJA_5 / sum(c_350ghz_JJA_5)
cdf_350ghz_JJA_5 = np.cumsum(pdf_350ghz_JJA_5)
#plt.plot(cdf_350ghz_JJA_5)

c_350ghz_JJA_50, b_350ghz_JJA_50= np.histogram(tau_submm_load_CCAT_350ghz_JJA_50)
pdf_350ghz_JJA_50 = c_350ghz_JJA_50 / sum(c_350ghz_JJA_50)
cdf_350ghz_JJA_50 = np.cumsum(pdf_350ghz_JJA_50)

c_350ghz_JJA_95, b_350ghz_JJA_95= np.histogram(tau_submm_load_CCAT_350ghz_JJA_95)
pdf_350ghz_JJA_95 = c_350ghz_JJA_95 / sum(c_350ghz_JJA_95)
cdf_350ghz_JJA_95 = np.cumsum(pdf_350ghz_JJA_95)

#-------------------------------------------------------------------------------------------SON-----------------------------------------------------------

c_350ghz_SON_5, b_350ghz_SON_5= np.histogram(tau_submm_load_CCAT_350ghz_SON_5)
pdf_350ghz_SON_5 = c_350ghz_SON_5 / sum(c_350ghz_SON_5)
cdf_350ghz_SON_5 = np.cumsum(pdf_350ghz_SON_5)
#plt.plot(cdf_350ghz_SON_5)

c_350ghz_SON_50, b_350ghz_SON_50= np.histogram(tau_submm_load_CCAT_350ghz_SON_50)
pdf_350ghz_SON_50 = c_350ghz_SON_50 / sum(c_350ghz_SON_50)
cdf_350ghz_SON_50 = np.cumsum(pdf_350ghz_SON_50)

c_350ghz_SON_95, b_350ghz_SON_95= np.histogram(tau_submm_load_CCAT_350ghz_SON_95)
pdf_350ghz_SON_95 = c_350ghz_SON_95 / sum(c_350ghz_SON_95)
cdf_350ghz_SON_95 = np.cumsum(pdf_350ghz_SON_95)

# %%
fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("350 GHz Transmission vs Elevation Angle (Alt= 5.6 Km| BW= 36 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_5,tx_submm_load_CCAT_350ghz_annual_5 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_50,tx_submm_load_CCAT_350ghz_annual_50 ,label ="$H_2O$: 50th percentile")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_95,tx_submm_load_CCAT_350ghz_annual_95 ,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_5,tx_submm_load_CCAT_350ghz_DJF_5 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_50,tx_submm_load_CCAT_350ghz_DJF_50 ,label ="$H_2O$: 50th percentile")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_95,tx_submm_load_CCAT_350ghz_DJF_95 ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_5,tx_submm_load_CCAT_350ghz_JFM_5 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_50,tx_submm_load_CCAT_350ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_95,tx_submm_load_CCAT_350ghz_JFM_95 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_5,tx_submm_load_CCAT_350ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_50,tx_submm_load_CCAT_350ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_95,tx_submm_load_CCAT_350ghz_MAM_95 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_5,tx_submm_load_CCAT_350ghz_JJA_5 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_50,tx_submm_load_CCAT_350ghz_JJA_50 ,label ="$H_2O$: 50th percentile")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_95,tx_submm_load_CCAT_350ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_5,tx_submm_load_CCAT_350ghz_SON_5 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_50,tx_submm_load_CCAT_350ghz_SON_50 ,label ="$H_2O$: 50th percentile")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_95,tx_submm_load_CCAT_350ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading txer (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, 'Atmospheric Transmission', va='center', rotation='vertical',size=14)


plt.savefig("350ghz_outputs/350 GHz Transmission vs Elevation Angle (Alt= 5.6 Km| BW= 36 GHz)_V1.jpg",dpi="figure")

plt.show()

# %%
fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("350 GHz Brightness Temperature vs Elevation Angle (Alt= 5.6 Km| BW= 36 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_5,tb_submm_load_CCAT_350ghz_annual_5 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_50,tb_submm_load_CCAT_350ghz_annual_50 ,label ="$H_2O$: 50th percentile")
#axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_95,tb_submm_load_CCAT_350ghz_annual_95 ,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_5,tb_submm_load_CCAT_350ghz_DJF_5 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_50,tb_submm_load_CCAT_350ghz_DJF_50 ,label ="$H_2O$: 50th percentile")
#axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_95,tb_submm_load_CCAT_350ghz_DJF_95 ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_5,tb_submm_load_CCAT_350ghz_JFM_5 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_50,tb_submm_load_CCAT_350ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
#axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_95,tb_submm_load_CCAT_350ghz_JFM_95 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_5,tb_submm_load_CCAT_350ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_50,tb_submm_load_CCAT_350ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
#axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_95,tb_submm_load_CCAT_350ghz_MAM_95 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_5,tb_submm_load_CCAT_350ghz_JJA_5 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_50,tb_submm_load_CCAT_350ghz_JJA_50 ,label ="$H_2O$: 50th percentile")
#axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_95,tb_submm_load_CCAT_350ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_5,tb_submm_load_CCAT_350ghz_SON_5 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_50,tb_submm_load_CCAT_350ghz_SON_50 ,label ="$H_2O$: 50th percentile")
#axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_95,tb_submm_load_CCAT_350ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading tber (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, ' $ T_{b} $(K)', va='center', rotation='vertical',size=14)


plt.savefig("350ghz_outputs/350 GHz Brightness Temperature vs Elevation Angle (Alt= 5.6 Km| BW= 36 GHz)_V1.jpg",dpi="figure")

plt.show()

# %%
fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("350 GHz Rayleigh Jeans Temperature vs Elevation Angle (Alt= 5.6 Km| BW= 36 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_5,trj_submm_load_CCAT_350ghz_annual_5 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_50,trj_submm_load_CCAT_350ghz_annual_50 ,label ="$H_2O$: 50th percentile")
#axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_95,trj_submm_load_CCAT_350ghz_annual_95 ,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_5,trj_submm_load_CCAT_350ghz_DJF_5 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_50,trj_submm_load_CCAT_350ghz_DJF_50 ,label ="$H_2O$: 50th percentile")
#axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_95,trj_submm_load_CCAT_350ghz_DJF_95 ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_5,trj_submm_load_CCAT_350ghz_JFM_5 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_50,trj_submm_load_CCAT_350ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
#axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_95,trj_submm_load_CCAT_350ghz_JFM_95 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_5,trj_submm_load_CCAT_350ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_50,trj_submm_load_CCAT_350ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
#axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_95,trj_submm_load_CCAT_350ghz_MAM_95 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_5,trj_submm_load_CCAT_350ghz_JJA_5 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_50,trj_submm_load_CCAT_350ghz_JJA_50 ,label ="$H_2O$: 50th percentile")
#axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_95,trj_submm_load_CCAT_350ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_5,trj_submm_load_CCAT_350ghz_SON_5 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_50,trj_submm_load_CCAT_350ghz_SON_50 ,label ="$H_2O$: 50th percentile")
#axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_95,trj_submm_load_CCAT_350ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading trjer (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, ' $ T_{rj} $(K)', va='center', rotation='vertical',size=14)


plt.savefig("350ghz_outputs/350 GHz Rayleigh Jeans Temperature vs Elevation Angle (Alt= 5.6 Km| BW= 36 GHz)_V1.jpg",dpi="figure")

plt.show()

# %%
fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("350 GHz Detector Loading Power vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 36 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_5,pow_submm_load_CCAT_350ghz_annual_5 *1e12,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_50,pow_submm_load_CCAT_350ghz_annual_50 *1e12,label ="$H_2O$: 50th percentile")
#axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_95,pow_submm_load_CCAT_350ghz_annual_95 *1e12,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_5,pow_submm_load_CCAT_350ghz_DJF_5 *1e12,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_50,pow_submm_load_CCAT_350ghz_DJF_50 *1e12,label ="$H_2O$: 50th percentile")
#axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_95,pow_submm_load_CCAT_350ghz_DJF_95 *1e12,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_5,pow_submm_load_CCAT_350ghz_JFM_5 *1e12,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_50,pow_submm_load_CCAT_350ghz_JFM_50 *1e12,label ="$H_2O$: 50th percentile")
#axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_95,pow_submm_load_CCAT_350ghz_JFM_95 *1e12,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_5,pow_submm_load_CCAT_350ghz_MAM_5 *1e12,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_50,pow_submm_load_CCAT_350ghz_MAM_50 *1e12,label ="$H_2O$: 50th percentile")
#axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_95,pow_submm_load_CCAT_350ghz_MAM_95 *1e12,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_5,pow_submm_load_CCAT_350ghz_JJA_5 *1e12,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_50,pow_submm_load_CCAT_350ghz_JJA_50 *1e12,label ="$H_2O$: 50th percentile")
#axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_95,pow_submm_load_CCAT_350ghz_JJA_95 *1e12,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_5,pow_submm_load_CCAT_350ghz_SON_5 *1e12,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_50,pow_submm_load_CCAT_350ghz_SON_50 *1e12,label ="$H_2O$: 50th percentile")
#axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_95,pow_submm_load_CCAT_350ghz_SON_95 *1e12,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading Power (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, ' Loading Power (pW)', va='center', rotation='vertical',size=14)


plt.savefig("350ghz_outputs/350 GHz Detector Loading Power vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 36 GHz)_V1.jpg",dpi="figure")

plt.show()

# %% [markdown]
# ### Responsivity vs Power Plot
# ##### (Responsivity measures the input–output gain of a detector system)
#
# #### (based on the TiN CCAT 280 GHz first array)

# %%
# 850 GHz BLAST-TNG array

Qr = 36380  # Quality factor
Qc = 58290  # Coupling factor
f0 = 800e6 #[Hz]

# %%
responsivity_data = np.loadtxt("responsivity_meas.txt")
# power_mes = (res.power* 10**-12).to_numpy()  # watts
# respon= (res.Responsivity* 10**8).to_numpy() 
power_mes = responsivity_data[:,0] * 1e-12  # in W
respon = responsivity_data[:,1]*1e8

# plotting the data

plt.figure(figsize=(7,5))
plt.plot(power_mes* 1e12,respon)
plt.title("Responsivity vs Power (TiN CCAT 280 GHz array)",size=14)
plt.xlabel("Power(Pw)",size=14)
plt.ylabel("Responsivity",size=14)

plt.savefig("350ghz_outputs/Responsivity vs Power (TiN CCAT 280 GHz array)_V1.jpg",dpi="figure")
plt.show()

# %% [markdown]
# #### frequency shifts ~ power at the detector * responsivity

# %%
# ----------------------------------------------------------------------------------------ANNUAL--------------------------------------------------------------

freq_shift_submm_load_CCAT_350ghz_annual_5 = pow_submm_load_CCAT_350ghz_annual_5 * respon  
freq_shift_submm_load_CCAT_350ghz_annual_50 = pow_submm_load_CCAT_350ghz_annual_50 * respon
freq_shift_submm_load_CCAT_350ghz_annual_95 = pow_submm_load_CCAT_350ghz_annual_95 * respon

# ----------------------------------------------------------------------------------------DJF--------------------------------------------------------------

freq_shift_submm_load_CCAT_350ghz_DJF_5 = pow_submm_load_CCAT_350ghz_DJF_5 * respon  
freq_shift_submm_load_CCAT_350ghz_DJF_50 = pow_submm_load_CCAT_350ghz_DJF_50 * respon
freq_shift_submm_load_CCAT_350ghz_DJF_95 = pow_submm_load_CCAT_350ghz_DJF_95 * respon

# ----------------------------------------------------------------------------------------JFM--------------------------------------------------------------

freq_shift_submm_load_CCAT_350ghz_JFM_5 = pow_submm_load_CCAT_350ghz_JFM_5 * respon  
freq_shift_submm_load_CCAT_350ghz_JFM_50 = pow_submm_load_CCAT_350ghz_JFM_50 * respon
freq_shift_submm_load_CCAT_350ghz_JFM_95 = pow_submm_load_CCAT_350ghz_JFM_95 * respon

# ----------------------------------------------------------------------------------------MAM--------------------------------------------------------------

freq_shift_submm_load_CCAT_350ghz_MAM_5 = pow_submm_load_CCAT_350ghz_MAM_5 * respon  
freq_shift_submm_load_CCAT_350ghz_MAM_50 = pow_submm_load_CCAT_350ghz_MAM_50 * respon
freq_shift_submm_load_CCAT_350ghz_MAM_95 = pow_submm_load_CCAT_350ghz_MAM_95 * respon

# ----------------------------------------------------------------------------------------JJA--------------------------------------------------------------

freq_shift_submm_load_CCAT_350ghz_JJA_5 = pow_submm_load_CCAT_350ghz_JJA_5 * respon  
freq_shift_submm_load_CCAT_350ghz_JJA_50 = pow_submm_load_CCAT_350ghz_JJA_50 * respon
freq_shift_submm_load_CCAT_350ghz_JJA_95 = pow_submm_load_CCAT_350ghz_JJA_95 * respon

# ----------------------------------------------------------------------------------------SON--------------------------------------------------------------

freq_shift_submm_load_CCAT_350ghz_SON_5 = pow_submm_load_CCAT_350ghz_SON_5 * respon  
freq_shift_submm_load_CCAT_350ghz_SON_50 = pow_submm_load_CCAT_350ghz_SON_50 * respon
freq_shift_submm_load_CCAT_350ghz_SON_95 = pow_submm_load_CCAT_350ghz_SON_95 * respon

# %%
## plotting the freqeuncy shifts

fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("350 GHz Detector frequency shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 36 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_5,freq_shift_submm_load_CCAT_350ghz_annual_5 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_50,freq_shift_submm_load_CCAT_350ghz_annual_50 ,label ="$H_2O$: 50th percentile")
#axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_95,freq_shift_submm_load_CCAT_350ghz_annual_95 ,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_5,freq_shift_submm_load_CCAT_350ghz_DJF_5 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_50,freq_shift_submm_load_CCAT_350ghz_DJF_50 ,label ="$H_2O$: 50th percentile")
#axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_95,freq_shift_submm_load_CCAT_350ghz_DJF_95 ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_5,freq_shift_submm_load_CCAT_350ghz_JFM_5 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_50,freq_shift_submm_load_CCAT_350ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
#axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_95,freq_shift_submm_load_CCAT_350ghz_JFM_95 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_5,freq_shift_submm_load_CCAT_350ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_50,freq_shift_submm_load_CCAT_350ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
#axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_95,freq_shift_submm_load_CCAT_350ghz_MAM_95 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_5,freq_shift_submm_load_CCAT_350ghz_JJA_5 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_50,freq_shift_submm_load_CCAT_350ghz_JJA_50 ,label ="$H_2O$: 50th percentile")
#axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_95,freq_shift_submm_load_CCAT_350ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_5,freq_shift_submm_load_CCAT_350ghz_SON_5 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_50,freq_shift_submm_load_CCAT_350ghz_SON_50 ,label ="$H_2O$: 50th percentile")
#axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_95,freq_shift_submm_load_CCAT_350ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading freq_shifter (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, ' Loading frequency shift', va='center', rotation='vertical',size=14)


plt.savefig("350ghz_outputs/350 GHz Detector frequency shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 36 GHz)_V1.jpg",dpi="figure")

plt.show()

# %% [markdown]
# #### Actual Frequency Shift ~ Responsivity * Resonant Frequency * change in power (for 5 deg skydip)

# %%
fres = 800e6 # resonant freq in Hz(800 MHz)

# %%
ea_submm_load_CCAT_350ghz_annual_5
# Out:
# array([85., 80., 75., 70., 65., 60., 55., 50., 45., 40., 35., 30., 25.,
#        20., 15., 10.,  5.])

# %%
pow_submm_load_CCAT_350ghz_annual_5
# Out:
# array([6.03504252e-13, 6.10193437e-13, 6.21621607e-13, 6.38235196e-13,
#        6.60719062e-13, 6.90069850e-13, 7.27713640e-13, 7.75696359e-13,
#        8.37000039e-13, 9.16088112e-13, 1.01989535e-12, 1.15974747e-12,
#        1.35541025e-12, 1.64463035e-12, 2.10932892e-12, 2.96573417e-12,
#        5.01698062e-12])

# %%
ea_submm_load_CCAT_350ghz_annual_5
# Out:
# array([85., 80., 75., 70., 65., 60., 55., 50., 45., 40., 35., 30., 25.,
#        20., 15., 10.,  5.])

# %%
# difference in the frequency shifts at each elevation angle

# ----------------------------------------------------------------------------------------ANNUAL--------------------------------------------------------------

del_pow_submm_load_CCAT_350ghz_annual_5 = np.diff(pow_submm_load_CCAT_350ghz_annual_5)
del_pow_submm_load_CCAT_350ghz_annual_50 = np.diff(pow_submm_load_CCAT_350ghz_annual_50)
del_pow_submm_load_CCAT_350ghz_annual_95 = np.diff(pow_submm_load_CCAT_350ghz_annual_95)

# ----------------------------------------------------------------------------------------DJF--------------------------------------------------------------

del_pow_submm_load_CCAT_350ghz_DJF_5 = np.diff(pow_submm_load_CCAT_350ghz_DJF_5)
del_pow_submm_load_CCAT_350ghz_DJF_50 = np.diff(pow_submm_load_CCAT_350ghz_DJF_50)
del_pow_submm_load_CCAT_350ghz_DJF_95 = np.diff(pow_submm_load_CCAT_350ghz_DJF_95)

# ----------------------------------------------------------------------------------------JFM--------------------------------------------------------------

del_pow_submm_load_CCAT_350ghz_JFM_5 = np.diff(pow_submm_load_CCAT_350ghz_JFM_5)
del_pow_submm_load_CCAT_350ghz_JFM_50 = np.diff(pow_submm_load_CCAT_350ghz_JFM_50)
del_pow_submm_load_CCAT_350ghz_JFM_95 = np.diff(pow_submm_load_CCAT_350ghz_JFM_95)

# ----------------------------------------------------------------------------------------MAM--------------------------------------------------------------

del_pow_submm_load_CCAT_350ghz_MAM_5 = np.diff(pow_submm_load_CCAT_350ghz_MAM_5)
del_pow_submm_load_CCAT_350ghz_MAM_50 = np.diff(pow_submm_load_CCAT_350ghz_MAM_50)
del_pow_submm_load_CCAT_350ghz_MAM_95 = np.diff(pow_submm_load_CCAT_350ghz_MAM_95)

# ----------------------------------------------------------------------------------------JJA--------------------------------------------------------------

del_pow_submm_load_CCAT_350ghz_JJA_5 = np.diff(pow_submm_load_CCAT_350ghz_JJA_5)
del_pow_submm_load_CCAT_350ghz_JJA_50 = np.diff(pow_submm_load_CCAT_350ghz_JJA_50)
del_pow_submm_load_CCAT_350ghz_JJA_95 = np.diff(pow_submm_load_CCAT_350ghz_JJA_95)

# ----------------------------------------------------------------------------------------SON--------------------------------------------------------------

del_pow_submm_load_CCAT_350ghz_SON_5 = np.diff(pow_submm_load_CCAT_350ghz_SON_5)
del_pow_submm_load_CCAT_350ghz_SON_50 = np.diff(pow_submm_load_CCAT_350ghz_SON_50)
del_pow_submm_load_CCAT_350ghz_SON_95 = np.diff(pow_submm_load_CCAT_350ghz_SON_95)

# %% [markdown]
# #### Actual Frequency Shift ~ Responsivity * Resonant Frequency * change in power (for 5 deg skydip)

# %%
# calculating the actual frequency shifts

act_freq_shift_submm_load_CCAT_350ghz_annual_5 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_annual_5 )
act_freq_shift_submm_load_CCAT_350ghz_annual_50 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_annual_50 )
act_freq_shift_submm_load_CCAT_350ghz_annual_95 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_annual_95 )

act_freq_shift_submm_load_CCAT_350ghz_DJF_5 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_DJF_5 )
act_freq_shift_submm_load_CCAT_350ghz_DJF_50 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_DJF_50 )
act_freq_shift_submm_load_CCAT_350ghz_DJF_95 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_DJF_95 )

act_freq_shift_submm_load_CCAT_350ghz_JFM_5 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_JFM_5 )
act_freq_shift_submm_load_CCAT_350ghz_JFM_50 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_JFM_50 )
act_freq_shift_submm_load_CCAT_350ghz_JFM_95 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_JFM_95 )

act_freq_shift_submm_load_CCAT_350ghz_MAM_5 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_MAM_5 )
act_freq_shift_submm_load_CCAT_350ghz_MAM_50 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_MAM_50 )
act_freq_shift_submm_load_CCAT_350ghz_MAM_95 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_MAM_95 )

act_freq_shift_submm_load_CCAT_350ghz_JJA_5 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_JJA_5 )
act_freq_shift_submm_load_CCAT_350ghz_JJA_50 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_JJA_50 )
act_freq_shift_submm_load_CCAT_350ghz_JJA_95 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_JJA_95 )

act_freq_shift_submm_load_CCAT_350ghz_SON_5 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_SON_5 )
act_freq_shift_submm_load_CCAT_350ghz_SON_50 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_SON_50 )
act_freq_shift_submm_load_CCAT_350ghz_SON_95 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_350ghz_SON_95 )

# %%
## plotting the freqeuncy shifts

fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("350 GHz Actual detector frequency shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 36 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_5[0:16],act_freq_shift_submm_load_CCAT_350ghz_annual_5 *1e-6 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_50[0:16],act_freq_shift_submm_load_CCAT_350ghz_annual_50 *1e-6 ,label ="$H_2O$: 50th percentile")
#axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_95[0:16],act_freq_shift_submm_load_CCAT_350ghz_annual_95 *1e-6,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_5[0:16],act_freq_shift_submm_load_CCAT_350ghz_DJF_5 *1e-6 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_50[0:16],act_freq_shift_submm_load_CCAT_350ghz_DJF_50 *1e-6 ,label ="$H_2O$: 50th percentile")
#axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_95[0:16],act_freq_shift_submm_load_CCAT_350ghz_DJF_95 *1e-6 ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_5[0:16],act_freq_shift_submm_load_CCAT_350ghz_JFM_5 *1e-6 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_50[0:16],act_freq_shift_submm_load_CCAT_350ghz_JFM_50 *1e-6,label ="$H_2O$: 50th percentile")
#axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_95[0:16],act_freq_shift_submm_load_CCAT_350ghz_JFM_95 *1e-6 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_5[0:16],act_freq_shift_submm_load_CCAT_350ghz_MAM_5 *1e-6,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_50[0:16],act_freq_shift_submm_load_CCAT_350ghz_MAM_50 *1e-6,label ="$H_2O$: 50th percentile")
#axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_95[0:16],act_freq_shift_submm_load_CCAT_350ghz_MAM_95 *1e-6 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_5[0:16],act_freq_shift_submm_load_CCAT_350ghz_JJA_5 *1e-6 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_50[0:16],act_freq_shift_submm_load_CCAT_350ghz_JJA_50 *1e-6 ,label ="$H_2O$: 50th percentile")
#axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_95[0:16],act_freq_shift_submm_load_CCAT_350ghz_JJA_95 *1e-6,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_5[0:16],act_freq_shift_submm_load_CCAT_350ghz_SON_5 *1e-6 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_50[0:16],act_freq_shift_submm_load_CCAT_350ghz_SON_50 *1e-6,label ="$H_2O$: 50th percentile")
#axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_95[0:16],act_freq_shift_submm_load_CCAT_350ghz_SON_95 *1e-6,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading act_freq_shifter (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, ' Actual frequency shift (MHz)', va='center', rotation='vertical',size=14)


plt.savefig("350ghz_outputs/350 GHz Actual detector frequency shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 36 GHz)_V1.jpg",dpi="figure")

plt.show()

# %%
act_freq_shift_submm_load_CCAT_350ghz_annual_5
# Out:
# array([  1265.29274512,   2036.64583617,   2789.87102539,   3647.71681124,
#          4588.35788245,   5711.78725724,   7112.52647396,   8832.20189691,
#         11065.59941594,  14228.8481657 ,  18802.24713842,  25834.62314392,
#         37491.36434451,  59119.82811466, 106329.60970293, 252883.1488397 ])

# %%
act_freq_shift_submm_load_CCAT_350ghz_annual_5[1] - act_freq_shift_submm_load_CCAT_350ghz_annual_5[0]
# Out:
# 771.3530910490472

# %%
ea_submm_load_CCAT_350ghz_annual_5
# Out:
# array([85., 80., 75., 70., 65., 60., 55., 50., 45., 40., 35., 30., 25.,
#        20., 15., 10.,  5.])

# %%
# ---------------------------------------------------------------------------deg shift gradient -----------------------------------------------------------------------------

deg_shifts_submm_load_CCAT_350ghz_annual_5 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_annual_5  # this amount of deg shift for a change in 2.2 KHz or 1/10 the line width of 22000 Hz
deg_shifts_submm_load_CCAT_350ghz_annual_50 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_annual_50
deg_shifts_submm_load_CCAT_350ghz_annual_95 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_annual_95

deg_shifts_submm_load_CCAT_350ghz_DJF_5 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_DJF_5  # this amount of deg shift for a change in 2.2 KHz or 1/10 the line width of 22000 Hz
deg_shifts_submm_load_CCAT_350ghz_DJF_50 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_DJF_50
deg_shifts_submm_load_CCAT_350ghz_DJF_95 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_DJF_95

deg_shifts_submm_load_CCAT_350ghz_JFM_5 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_JFM_5  # this amount of deg shift for a change in 2.2 KHz or 1/10 the line width of 22000 Hz
deg_shifts_submm_load_CCAT_350ghz_JFM_50 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_JFM_50
deg_shifts_submm_load_CCAT_350ghz_JFM_95 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_JFM_95

deg_shifts_submm_load_CCAT_350ghz_MAM_5 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_MAM_5  # this amount of deg shift for a change in 2.2 KHz or 1/10 the line width of 22000 Hz
deg_shifts_submm_load_CCAT_350ghz_MAM_50 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_MAM_50
deg_shifts_submm_load_CCAT_350ghz_MAM_95 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_MAM_95

deg_shifts_submm_load_CCAT_350ghz_JJA_5 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_JJA_5  # this amount of deg shift for a change in 2.2 KHz or 1/10 the line width of 22000 Hz
deg_shifts_submm_load_CCAT_350ghz_JJA_50 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_JJA_50
deg_shifts_submm_load_CCAT_350ghz_JJA_95 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_JJA_95

deg_shifts_submm_load_CCAT_350ghz_SON_5 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_SON_5  # this amount of deg shift for a change in 2.2 KHz or 1/10 the line width of 22000 Hz
deg_shifts_submm_load_CCAT_350ghz_SON_50 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_SON_50
deg_shifts_submm_load_CCAT_350ghz_SON_95 = (2200*5)/act_freq_shift_submm_load_CCAT_350ghz_SON_95

# %%
plt.plot(ea_submm_load_CCAT_350ghz_annual_50[0:16],deg_shifts_submm_load_CCAT_350ghz_annual_50)
#plt.title("Change in elevation (deg) to get a 2.2 KHz frequency shift")
plt.ylabel("Change in Elevation for a 2.2 KHz freq shift (deg)")
plt.xlabel("Elevation angle (deg)")
plt.yticks(np.arange(min(deg_shifts_submm_load_CCAT_350ghz_annual_50), max(deg_shifts_submm_load_CCAT_350ghz_annual_50), 0.1))
plt.show()

# %%
## plotting the freqeuncy shifts

fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("350 GHz : Change in Elevation angle (deg) for a 2.2 KHz shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 36 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_5[0:16],deg_shifts_submm_load_CCAT_350ghz_annual_5  ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_50[0:16],deg_shifts_submm_load_CCAT_350ghz_annual_50  ,label ="$H_2O$: 50th percentile")
axs[0][0].plot(ea_submm_load_CCAT_350ghz_annual_95[0:16],deg_shifts_submm_load_CCAT_350ghz_annual_95 ,label ="$H_2O$: 95th percentile")
#axs[0][0].yticks(np.arange(min(deg_shifts_submm_load_CCAT_350ghz_annual_50), max(deg_shifts_submm_load_CCAT_350ghz_annual_50), 0.1))
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_5[0:16],deg_shifts_submm_load_CCAT_350ghz_DJF_5  ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_50[0:16],deg_shifts_submm_load_CCAT_350ghz_DJF_50  ,label ="$H_2O$: 50th percentile")
axs[0][1].plot(ea_submm_load_CCAT_350ghz_DJF_95[0:16],deg_shifts_submm_load_CCAT_350ghz_DJF_95  ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_5[0:16],deg_shifts_submm_load_CCAT_350ghz_JFM_5  ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_50[0:16],deg_shifts_submm_load_CCAT_350ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
axs[0][2].plot(ea_submm_load_CCAT_350ghz_JFM_95[0:16],deg_shifts_submm_load_CCAT_350ghz_JFM_95  ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_5[0:16],deg_shifts_submm_load_CCAT_350ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_50[0:16],deg_shifts_submm_load_CCAT_350ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
axs[1][0].plot(ea_submm_load_CCAT_350ghz_MAM_95[0:16],deg_shifts_submm_load_CCAT_350ghz_MAM_95  ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_5[0:16],deg_shifts_submm_load_CCAT_350ghz_JJA_5  ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_50[0:16],deg_shifts_submm_load_CCAT_350ghz_JJA_50  ,label ="$H_2O$: 50th percentile")
axs[1][1].plot(ea_submm_load_CCAT_350ghz_JJA_95[0:16],deg_shifts_submm_load_CCAT_350ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_5[0:16],deg_shifts_submm_load_CCAT_350ghz_SON_5  ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_50[0:16],deg_shifts_submm_load_CCAT_350ghz_SON_50 ,label ="$H_2O$: 50th percentile")
axs[1][2].plot(ea_submm_load_CCAT_350ghz_SON_95[0:16],deg_shifts_submm_load_CCAT_350ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading act_freq_shifter (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, 'Change in Elevation for a 2.2 KHz freq shift (deg)', va='center', rotation='vertical',size=14)


plt.savefig("350ghz_outputs/350 GHz : Change in Elevation angle (deg) for a 2.2 KHz shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 36 GHz)_V1.jpg",dpi="figure")

plt.show()

# %% [markdown]
# ### FWHM = $ \frac{f_{res}}{Q_r} = \frac{800 MHz}{36380} = 22,000  Hz $
#
# ### $\frac{1}{10}$ of the Line width = $ 2.2 KHz $  (Linear Regime)
