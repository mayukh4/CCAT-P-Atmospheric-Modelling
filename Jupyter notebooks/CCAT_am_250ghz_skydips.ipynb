# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as ss
plt.rcParams['axes.grid'] = True

# %% [markdown]
# ### Skydips at 250 GHz ( i.e from 230 GHz to 273 GHz with 10 MHz resolution, 43 GHz bandwidth ) set at 5.6 KMs
#
# #### power loading at the detectors and fractional frequency shifts as a function of elevation angle
#
# #### output:Z(km), ZA(deg), f(GHz), tau, tx, Trj(K), Tb(K)
#
# #### EA = 90 - ZA
#
# #### power at the detector = T_rj * k * bw(Hz)

# %%
# defining constants 

k = 1.38064e-23 #boltzman constant
bw = 43e9 #Hz
eff =0.3 # 30% detector efficiency

# %%
#------------------------------------------------------------------ loading data --------------------------------------------------------------


#------------------------------------------------------------------ANNUAL----------------------------------------------------------------

submm_load_CCAT_250ghz_annual_5 = np.loadtxt("submm_load_CCAT_250ghz_annual_5_skydip.out")
submm_load_CCAT_250ghz_annual_50 = np.loadtxt("submm_load_CCAT_250ghz_annual_50_skydip.out")
submm_load_CCAT_250ghz_annual_95 = np.loadtxt("submm_load_CCAT_250ghz_annual_95_skydip.out")

# extracting the parameters

ea_submm_load_CCAT_250ghz_annual_5 = 90-submm_load_CCAT_250ghz_annual_5[:,1]
f_submm_load_CCAT_250ghz_annual_5 = submm_load_CCAT_250ghz_annual_5[:,2]
tau_submm_load_CCAT_250ghz_annual_5 =submm_load_CCAT_250ghz_annual_5[:,3]
tx_submm_load_CCAT_250ghz_annual_5 =submm_load_CCAT_250ghz_annual_5[:,4]
trj_submm_load_CCAT_250ghz_annual_5 = submm_load_CCAT_250ghz_annual_5[:,5]
tb_submm_load_CCAT_250ghz_annual_5 = submm_load_CCAT_250ghz_annual_5[:,6]



ea_submm_load_CCAT_250ghz_annual_50 = 90-submm_load_CCAT_250ghz_annual_50[:,1]
f_submm_load_CCAT_250ghz_annual_50 = submm_load_CCAT_250ghz_annual_50[:,2]
tau_submm_load_CCAT_250ghz_annual_50 =submm_load_CCAT_250ghz_annual_50[:,3]
tx_submm_load_CCAT_250ghz_annual_50 =submm_load_CCAT_250ghz_annual_50[:,4]
trj_submm_load_CCAT_250ghz_annual_50 = submm_load_CCAT_250ghz_annual_50[:,5]
tb_submm_load_CCAT_250ghz_annual_50 = submm_load_CCAT_250ghz_annual_50[:,6]

ea_submm_load_CCAT_250ghz_annual_95 = 90-submm_load_CCAT_250ghz_annual_95[:,1]
f_submm_load_CCAT_250ghz_annual_95 = submm_load_CCAT_250ghz_annual_95[:,2]
tau_submm_load_CCAT_250ghz_annual_95 =submm_load_CCAT_250ghz_annual_95[:,3]
tx_submm_load_CCAT_250ghz_annual_95 =submm_load_CCAT_250ghz_annual_95[:,4]
trj_submm_load_CCAT_250ghz_annual_95 = submm_load_CCAT_250ghz_annual_95[:,5]
tb_submm_load_CCAT_250ghz_annual_95 = submm_load_CCAT_250ghz_annual_95[:,6]



#------------------------------------------------------------------DJF----------------------------------------------------------------

submm_load_CCAT_250ghz_DJF_5 = np.loadtxt("submm_load_CCAT_250ghz_DJF_5_skydip.out")
submm_load_CCAT_250ghz_DJF_50 = np.loadtxt("submm_load_CCAT_250ghz_DJF_50_skydip.out")
submm_load_CCAT_250ghz_DJF_95 = np.loadtxt("submm_load_CCAT_250ghz_DJF_95_skydip.out")

# extracting the parameters

ea_submm_load_CCAT_250ghz_DJF_5 = 90-submm_load_CCAT_250ghz_DJF_5[:,1]
f_submm_load_CCAT_250ghz_DJF_5 = submm_load_CCAT_250ghz_DJF_5[:,2]
tau_submm_load_CCAT_250ghz_DJF_5 =submm_load_CCAT_250ghz_DJF_5[:,3]
tx_submm_load_CCAT_250ghz_DJF_5 =submm_load_CCAT_250ghz_DJF_5[:,4]
trj_submm_load_CCAT_250ghz_DJF_5 = submm_load_CCAT_250ghz_DJF_5[:,5]
tb_submm_load_CCAT_250ghz_DJF_5 = submm_load_CCAT_250ghz_DJF_5[:,6]

ea_submm_load_CCAT_250ghz_DJF_50 = 90-submm_load_CCAT_250ghz_DJF_50[:,1]
f_submm_load_CCAT_250ghz_DJF_50 = submm_load_CCAT_250ghz_DJF_50[:,2]
tau_submm_load_CCAT_250ghz_DJF_50 =submm_load_CCAT_250ghz_DJF_50[:,3]
tx_submm_load_CCAT_250ghz_DJF_50 =submm_load_CCAT_250ghz_DJF_50[:,4]
trj_submm_load_CCAT_250ghz_DJF_50 = submm_load_CCAT_250ghz_DJF_50[:,5]
tb_submm_load_CCAT_250ghz_DJF_50 = submm_load_CCAT_250ghz_DJF_50[:,6]

ea_submm_load_CCAT_250ghz_DJF_95 = 90-submm_load_CCAT_250ghz_DJF_95[:,1]
f_submm_load_CCAT_250ghz_DJF_95 = submm_load_CCAT_250ghz_DJF_95[:,2]
tau_submm_load_CCAT_250ghz_DJF_95 =submm_load_CCAT_250ghz_DJF_95[:,3]
tx_submm_load_CCAT_250ghz_DJF_95 =submm_load_CCAT_250ghz_DJF_95[:,4]
trj_submm_load_CCAT_250ghz_DJF_95 = submm_load_CCAT_250ghz_DJF_95[:,5]
tb_submm_load_CCAT_250ghz_DJF_95 = submm_load_CCAT_250ghz_DJF_95[:,6]


#------------------------------------------------------------------JFM----------------------------------------------------------------

submm_load_CCAT_250ghz_JFM_5 = np.loadtxt("submm_load_CCAT_250ghz_JFM_5_skydip.out")
submm_load_CCAT_250ghz_JFM_50 = np.loadtxt("submm_load_CCAT_250ghz_JFM_50_skydip.out")
submm_load_CCAT_250ghz_JFM_95 = np.loadtxt("submm_load_CCAT_250ghz_JFM_95_skydip.out")

# extracting the parameters

ea_submm_load_CCAT_250ghz_JFM_5 = 90-submm_load_CCAT_250ghz_JFM_5[:,1]
f_submm_load_CCAT_250ghz_JFM_5 = submm_load_CCAT_250ghz_JFM_5[:,2]
tau_submm_load_CCAT_250ghz_JFM_5 =submm_load_CCAT_250ghz_JFM_5[:,3]
tx_submm_load_CCAT_250ghz_JFM_5 =submm_load_CCAT_250ghz_JFM_5[:,4]
trj_submm_load_CCAT_250ghz_JFM_5 = submm_load_CCAT_250ghz_JFM_5[:,5]
tb_submm_load_CCAT_250ghz_JFM_5 = submm_load_CCAT_250ghz_JFM_5[:,6]

ea_submm_load_CCAT_250ghz_JFM_50 = 90-submm_load_CCAT_250ghz_JFM_50[:,1]
f_submm_load_CCAT_250ghz_JFM_50 = submm_load_CCAT_250ghz_JFM_50[:,2]
tau_submm_load_CCAT_250ghz_JFM_50 =submm_load_CCAT_250ghz_JFM_50[:,3]
tx_submm_load_CCAT_250ghz_JFM_50 =submm_load_CCAT_250ghz_JFM_50[:,4]
trj_submm_load_CCAT_250ghz_JFM_50 = submm_load_CCAT_250ghz_JFM_50[:,5]
tb_submm_load_CCAT_250ghz_JFM_50 = submm_load_CCAT_250ghz_JFM_50[:,6]

ea_submm_load_CCAT_250ghz_JFM_95 = 90-submm_load_CCAT_250ghz_JFM_95[:,1]
f_submm_load_CCAT_250ghz_JFM_95 = submm_load_CCAT_250ghz_JFM_95[:,2]
tau_submm_load_CCAT_250ghz_JFM_95 =submm_load_CCAT_250ghz_JFM_95[:,3]
tx_submm_load_CCAT_250ghz_JFM_95 =submm_load_CCAT_250ghz_JFM_95[:,4]
trj_submm_load_CCAT_250ghz_JFM_95 = submm_load_CCAT_250ghz_JFM_95[:,5]
tb_submm_load_CCAT_250ghz_JFM_95 = submm_load_CCAT_250ghz_JFM_95[:,6]


#------------------------------------------------------------------MAM----------------------------------------------------------------

submm_load_CCAT_250ghz_MAM_5 = np.loadtxt("submm_load_CCAT_250ghz_MAM_5_skydip.out")
submm_load_CCAT_250ghz_MAM_50 = np.loadtxt("submm_load_CCAT_250ghz_MAM_50_skydip.out")
submm_load_CCAT_250ghz_MAM_95 = np.loadtxt("submm_load_CCAT_250ghz_MAM_95_skydip.out")

# extracting the parameters

ea_submm_load_CCAT_250ghz_MAM_5 = 90-submm_load_CCAT_250ghz_MAM_5[:,1]
f_submm_load_CCAT_250ghz_MAM_5 = submm_load_CCAT_250ghz_MAM_5[:,2]
tau_submm_load_CCAT_250ghz_MAM_5 =submm_load_CCAT_250ghz_MAM_5[:,3]
tx_submm_load_CCAT_250ghz_MAM_5 =submm_load_CCAT_250ghz_MAM_5[:,4]
trj_submm_load_CCAT_250ghz_MAM_5 = submm_load_CCAT_250ghz_MAM_5[:,5]
tb_submm_load_CCAT_250ghz_MAM_5 = submm_load_CCAT_250ghz_MAM_5[:,6]

ea_submm_load_CCAT_250ghz_MAM_50 = 90-submm_load_CCAT_250ghz_MAM_50[:,1]
f_submm_load_CCAT_250ghz_MAM_50 = submm_load_CCAT_250ghz_MAM_50[:,2]
tau_submm_load_CCAT_250ghz_MAM_50 =submm_load_CCAT_250ghz_MAM_50[:,3]
tx_submm_load_CCAT_250ghz_MAM_50 =submm_load_CCAT_250ghz_MAM_50[:,4]
trj_submm_load_CCAT_250ghz_MAM_50 = submm_load_CCAT_250ghz_MAM_50[:,5]
tb_submm_load_CCAT_250ghz_MAM_50 = submm_load_CCAT_250ghz_MAM_50[:,6]

ea_submm_load_CCAT_250ghz_MAM_95 = 90-submm_load_CCAT_250ghz_MAM_95[:,1]
f_submm_load_CCAT_250ghz_MAM_95 = submm_load_CCAT_250ghz_MAM_95[:,2]
tau_submm_load_CCAT_250ghz_MAM_95 =submm_load_CCAT_250ghz_MAM_95[:,3]
tx_submm_load_CCAT_250ghz_MAM_95 =submm_load_CCAT_250ghz_MAM_95[:,4]
trj_submm_load_CCAT_250ghz_MAM_95 = submm_load_CCAT_250ghz_MAM_95[:,5]
tb_submm_load_CCAT_250ghz_MAM_95 = submm_load_CCAT_250ghz_MAM_95[:,6]

#------------------------------------------------------------------JJA----------------------------------------------------------------

submm_load_CCAT_250ghz_JJA_5 = np.loadtxt("submm_load_CCAT_250ghz_JJA_5_skydip.out")
submm_load_CCAT_250ghz_JJA_50 = np.loadtxt("submm_load_CCAT_250ghz_JJA_50_skydip.out")
submm_load_CCAT_250ghz_JJA_95 = np.loadtxt("submm_load_CCAT_250ghz_JJA_95_skydip.out")

# extracting the parameters

ea_submm_load_CCAT_250ghz_JJA_5 = 90-submm_load_CCAT_250ghz_JJA_5[:,1]
f_submm_load_CCAT_250ghz_JJA_5 = submm_load_CCAT_250ghz_JJA_5[:,2]
tau_submm_load_CCAT_250ghz_JJA_5 =submm_load_CCAT_250ghz_JJA_5[:,3]
tx_submm_load_CCAT_250ghz_JJA_5 =submm_load_CCAT_250ghz_JJA_5[:,4]
trj_submm_load_CCAT_250ghz_JJA_5 = submm_load_CCAT_250ghz_JJA_5[:,5]
tb_submm_load_CCAT_250ghz_JJA_5 = submm_load_CCAT_250ghz_JJA_5[:,6]

ea_submm_load_CCAT_250ghz_JJA_50 = 90-submm_load_CCAT_250ghz_JJA_50[:,1]
f_submm_load_CCAT_250ghz_JJA_50 = submm_load_CCAT_250ghz_JJA_50[:,2]
tau_submm_load_CCAT_250ghz_JJA_50 =submm_load_CCAT_250ghz_JJA_50[:,3]
tx_submm_load_CCAT_250ghz_JJA_50 =submm_load_CCAT_250ghz_JJA_50[:,4]
trj_submm_load_CCAT_250ghz_JJA_50 = submm_load_CCAT_250ghz_JJA_50[:,5]
tb_submm_load_CCAT_250ghz_JJA_50 = submm_load_CCAT_250ghz_JJA_50[:,6]

ea_submm_load_CCAT_250ghz_JJA_95 = 90-submm_load_CCAT_250ghz_JJA_95[:,1]
f_submm_load_CCAT_250ghz_JJA_95 = submm_load_CCAT_250ghz_JJA_95[:,2]
tau_submm_load_CCAT_250ghz_JJA_95 =submm_load_CCAT_250ghz_JJA_95[:,3]
tx_submm_load_CCAT_250ghz_JJA_95 =submm_load_CCAT_250ghz_JJA_95[:,4]
trj_submm_load_CCAT_250ghz_JJA_95 = submm_load_CCAT_250ghz_JJA_95[:,5]
tb_submm_load_CCAT_250ghz_JJA_95 = submm_load_CCAT_250ghz_JJA_95[:,6]

#------------------------------------------------------------------SON----------------------------------------------------------------

submm_load_CCAT_250ghz_SON_5 = np.loadtxt("submm_load_CCAT_250ghz_SON_5_skydip.out")
submm_load_CCAT_250ghz_SON_50 = np.loadtxt("submm_load_CCAT_250ghz_SON_50_skydip.out")
submm_load_CCAT_250ghz_SON_95 = np.loadtxt("submm_load_CCAT_250ghz_SON_95_skydip.out")

# extracting the parameters

ea_submm_load_CCAT_250ghz_SON_5 = 90-submm_load_CCAT_250ghz_SON_5[:,1]
f_submm_load_CCAT_250ghz_SON_5 = submm_load_CCAT_250ghz_SON_5[:,2]
tau_submm_load_CCAT_250ghz_SON_5 =submm_load_CCAT_250ghz_SON_5[:,3]
tx_submm_load_CCAT_250ghz_SON_5 =submm_load_CCAT_250ghz_SON_5[:,4]
trj_submm_load_CCAT_250ghz_SON_5 = submm_load_CCAT_250ghz_SON_5[:,5]
tb_submm_load_CCAT_250ghz_SON_5 = submm_load_CCAT_250ghz_SON_5[:,6]

ea_submm_load_CCAT_250ghz_SON_50 = 90-submm_load_CCAT_250ghz_SON_50[:,1]
f_submm_load_CCAT_250ghz_SON_50 = submm_load_CCAT_250ghz_SON_50[:,2]
tau_submm_load_CCAT_250ghz_SON_50 =submm_load_CCAT_250ghz_SON_50[:,3]
tx_submm_load_CCAT_250ghz_SON_50 =submm_load_CCAT_250ghz_SON_50[:,4]
trj_submm_load_CCAT_250ghz_SON_50 = submm_load_CCAT_250ghz_SON_50[:,5]
tb_submm_load_CCAT_250ghz_SON_50 = submm_load_CCAT_250ghz_SON_50[:,6]

ea_submm_load_CCAT_250ghz_SON_95 = 90-submm_load_CCAT_250ghz_SON_95[:,1]
f_submm_load_CCAT_250ghz_SON_95 = submm_load_CCAT_250ghz_SON_95[:,2]
tau_submm_load_CCAT_250ghz_SON_95 =submm_load_CCAT_250ghz_SON_95[:,3]
tx_submm_load_CCAT_250ghz_SON_95 =submm_load_CCAT_250ghz_SON_95[:,4]
trj_submm_load_CCAT_250ghz_SON_95 = submm_load_CCAT_250ghz_SON_95[:,5]
tb_submm_load_CCAT_250ghz_SON_95 = submm_load_CCAT_250ghz_SON_95[:,6]

# %%
# power loading at the detectors in W

#-------------------------------------------------------------------------------------------ANNUAL-----------------------------------------------------------

pow_submm_load_CCAT_250ghz_annual_5 = eff * trj_submm_load_CCAT_250ghz_annual_5 * k * bw 
pow_submm_load_CCAT_250ghz_annual_50 = eff * trj_submm_load_CCAT_250ghz_annual_50 * k * bw 
pow_submm_load_CCAT_250ghz_annual_95 = eff * trj_submm_load_CCAT_250ghz_annual_95 * k * bw 

#------------------------------------------------------------------------------------------DJF----------------------------------------------------------------
pow_submm_load_CCAT_250ghz_DJF_5 = eff * trj_submm_load_CCAT_250ghz_DJF_5 * k * bw 
pow_submm_load_CCAT_250ghz_DJF_50 = eff * trj_submm_load_CCAT_250ghz_DJF_50 * k * bw 
pow_submm_load_CCAT_250ghz_DJF_95 = eff * trj_submm_load_CCAT_250ghz_DJF_95 * k * bw 

#------------------------------------------------------------------------------------------JFM----------------------------------------------------------------
pow_submm_load_CCAT_250ghz_JFM_5 = eff * trj_submm_load_CCAT_250ghz_JFM_5 * k * bw 
pow_submm_load_CCAT_250ghz_JFM_50 = eff * trj_submm_load_CCAT_250ghz_JFM_50 * k * bw 
pow_submm_load_CCAT_250ghz_JFM_95 = eff * trj_submm_load_CCAT_250ghz_JFM_95 * k * bw 

#------------------------------------------------------------------------------------------MAM----------------------------------------------------------------
pow_submm_load_CCAT_250ghz_MAM_5 = eff * trj_submm_load_CCAT_250ghz_MAM_5 * k * bw 
pow_submm_load_CCAT_250ghz_MAM_50 = eff * trj_submm_load_CCAT_250ghz_MAM_50 * k * bw 
pow_submm_load_CCAT_250ghz_MAM_95 = eff * trj_submm_load_CCAT_250ghz_MAM_95 * k * bw 

#------------------------------------------------------------------------------------------JJA----------------------------------------------------------------
pow_submm_load_CCAT_250ghz_JJA_5 = eff * trj_submm_load_CCAT_250ghz_JJA_5 * k * bw 
pow_submm_load_CCAT_250ghz_JJA_50 = eff * trj_submm_load_CCAT_250ghz_JJA_50 * k * bw 
pow_submm_load_CCAT_250ghz_JJA_95 = eff * trj_submm_load_CCAT_250ghz_JJA_95 * k * bw 

#------------------------------------------------------------------------------------------SON----------------------------------------------------------------
pow_submm_load_CCAT_250ghz_SON_5 = eff * trj_submm_load_CCAT_250ghz_SON_5 * k * bw 
pow_submm_load_CCAT_250ghz_SON_50 = eff * trj_submm_load_CCAT_250ghz_SON_50 * k * bw 
pow_submm_load_CCAT_250ghz_SON_95 = eff * trj_submm_load_CCAT_250ghz_SON_95 * k * bw

# %%
fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("250 GHz Atmospheric Opacity vs Elevation Angle (Alt= 5.6 Km| BW= 43 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_5,tau_submm_load_CCAT_250ghz_annual_5 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_50,tau_submm_load_CCAT_250ghz_annual_50 ,label ="$H_2O$: 50th percentile")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_95,tau_submm_load_CCAT_250ghz_annual_95 ,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_5,tau_submm_load_CCAT_250ghz_DJF_5 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_50,tau_submm_load_CCAT_250ghz_DJF_50 ,label ="$H_2O$: 50th percentile")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_95,tau_submm_load_CCAT_250ghz_DJF_95 ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_5,tau_submm_load_CCAT_250ghz_JFM_5 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_50,tau_submm_load_CCAT_250ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_95,tau_submm_load_CCAT_250ghz_JFM_95 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_5,tau_submm_load_CCAT_250ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_50,tau_submm_load_CCAT_250ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_95,tau_submm_load_CCAT_250ghz_MAM_95 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_5,tau_submm_load_CCAT_250ghz_JJA_5 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_50,tau_submm_load_CCAT_250ghz_JJA_50 ,label ="$H_2O$: 50th percentile")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_95,tau_submm_load_CCAT_250ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_5,tau_submm_load_CCAT_250ghz_SON_5 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_50,tau_submm_load_CCAT_250ghz_SON_50 ,label ="$H_2O$: 50th percentile")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_95,tau_submm_load_CCAT_250ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading tauer (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, 'Atmospheric Opacity', va='center', rotation='vertical',size=14)


plt.savefig("250ghz_outputs/250 GHz Atmospheric Opacity vs Elevation Angle (Alt= 5.6 Km| BW= 43 GHz)_V1.jpg",dpi="figure")

plt.show()

# %%
# calculating the cumulative fraction as a fuction of the optical depth/opacity tau

#-------------------------------------------------------------------------------------------ANNUAL-----------------------------------------------------------

data_submm_load_CCAT_250ghz_annual_5 = tau_submm_load_CCAT_250ghz_annual_5
data_sorted_submm_load_CCAT_250ghz_annual_5 = np.sort(data_submm_load_CCAT_250ghz_annual_5)
p_submm_load_CCAT_250ghz_annual_5 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_annual_5)) / (len(data_submm_load_CCAT_250ghz_annual_5) - 1)

data_submm_load_CCAT_250ghz_annual_50 = tau_submm_load_CCAT_250ghz_annual_50
data_sorted_submm_load_CCAT_250ghz_annual_50 = np.sort(data_submm_load_CCAT_250ghz_annual_50)
p_submm_load_CCAT_250ghz_annual_50 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_annual_50)) / (len(data_submm_load_CCAT_250ghz_annual_50) - 1)

data_submm_load_CCAT_250ghz_annual_95 = tau_submm_load_CCAT_250ghz_annual_95
data_sorted_submm_load_CCAT_250ghz_annual_95 = np.sort(data_submm_load_CCAT_250ghz_annual_95)
p_submm_load_CCAT_250ghz_annual_95 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_annual_95)) / (len(data_submm_load_CCAT_250ghz_annual_95) - 1)

# calculating the cumulative fraction as a fuction of the optical depth/opacity tau

#-------------------------------------------------------------------------------------------DJF-----------------------------------------------------------

data_submm_load_CCAT_250ghz_DJF_5 = tau_submm_load_CCAT_250ghz_DJF_5
data_sorted_submm_load_CCAT_250ghz_DJF_5 = np.sort(data_submm_load_CCAT_250ghz_DJF_5)
p_submm_load_CCAT_250ghz_DJF_5 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_DJF_5)) / (len(data_submm_load_CCAT_250ghz_DJF_5) - 1)

data_submm_load_CCAT_250ghz_DJF_50 = tau_submm_load_CCAT_250ghz_DJF_50
data_sorted_submm_load_CCAT_250ghz_DJF_50 = np.sort(data_submm_load_CCAT_250ghz_DJF_50)
p_submm_load_CCAT_250ghz_DJF_50 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_DJF_50)) / (len(data_submm_load_CCAT_250ghz_DJF_50) - 1)

data_submm_load_CCAT_250ghz_DJF_95 = tau_submm_load_CCAT_250ghz_DJF_95
data_sorted_submm_load_CCAT_250ghz_DJF_95 = np.sort(data_submm_load_CCAT_250ghz_DJF_95)
p_submm_load_CCAT_250ghz_DJF_95 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_DJF_95)) / (len(data_submm_load_CCAT_250ghz_DJF_95) - 1)

# calculating the cumulative fraction as a fuction of the optical depth/opacity tau
#-------------------------------------------------------------------------------------------JFM-----------------------------------------------------------

data_submm_load_CCAT_250ghz_JFM_5 = tau_submm_load_CCAT_250ghz_JFM_5
data_sorted_submm_load_CCAT_250ghz_JFM_5 = np.sort(data_submm_load_CCAT_250ghz_JFM_5)
p_submm_load_CCAT_250ghz_JFM_5 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_JFM_5)) / (len(data_submm_load_CCAT_250ghz_JFM_5) - 1)

data_submm_load_CCAT_250ghz_JFM_50 = tau_submm_load_CCAT_250ghz_JFM_50
data_sorted_submm_load_CCAT_250ghz_JFM_50 = np.sort(data_submm_load_CCAT_250ghz_JFM_50)
p_submm_load_CCAT_250ghz_JFM_50 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_JFM_50)) / (len(data_submm_load_CCAT_250ghz_JFM_50) - 1)

data_submm_load_CCAT_250ghz_JFM_95 = tau_submm_load_CCAT_250ghz_JFM_95
data_sorted_submm_load_CCAT_250ghz_JFM_95 = np.sort(data_submm_load_CCAT_250ghz_JFM_95)
p_submm_load_CCAT_250ghz_JFM_95 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_JFM_95)) / (len(data_submm_load_CCAT_250ghz_JFM_95) - 1)

# calculating the cumulative fraction as a fuction of the optical depth/opacity tau
#-------------------------------------------------------------------------------------------MAM-----------------------------------------------------------

data_submm_load_CCAT_250ghz_MAM_5 = tau_submm_load_CCAT_250ghz_MAM_5
data_sorted_submm_load_CCAT_250ghz_MAM_5 = np.sort(data_submm_load_CCAT_250ghz_MAM_5)
p_submm_load_CCAT_250ghz_MAM_5 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_MAM_5)) / (len(data_submm_load_CCAT_250ghz_MAM_5) - 1)

data_submm_load_CCAT_250ghz_MAM_50 = tau_submm_load_CCAT_250ghz_MAM_50
data_sorted_submm_load_CCAT_250ghz_MAM_50 = np.sort(data_submm_load_CCAT_250ghz_MAM_50)
p_submm_load_CCAT_250ghz_MAM_50 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_MAM_50)) / (len(data_submm_load_CCAT_250ghz_MAM_50) - 1)

data_submm_load_CCAT_250ghz_MAM_95 = tau_submm_load_CCAT_250ghz_MAM_95
data_sorted_submm_load_CCAT_250ghz_MAM_95 = np.sort(data_submm_load_CCAT_250ghz_MAM_95)
p_submm_load_CCAT_250ghz_MAM_95 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_MAM_95)) / (len(data_submm_load_CCAT_250ghz_MAM_95) - 1)

# calculating the cumulative fraction as a fuction of the optical depth/opacity tau
#-------------------------------------------------------------------------------------------JJA-----------------------------------------------------------

data_submm_load_CCAT_250ghz_JJA_5 = tau_submm_load_CCAT_250ghz_JJA_5
data_sorted_submm_load_CCAT_250ghz_JJA_5 = np.sort(data_submm_load_CCAT_250ghz_JJA_5)
p_submm_load_CCAT_250ghz_JJA_5 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_JJA_5)) / (len(data_submm_load_CCAT_250ghz_JJA_5) - 1)

data_submm_load_CCAT_250ghz_JJA_50 = tau_submm_load_CCAT_250ghz_JJA_50
data_sorted_submm_load_CCAT_250ghz_JJA_50 = np.sort(data_submm_load_CCAT_250ghz_JJA_50)
p_submm_load_CCAT_250ghz_JJA_50 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_JJA_50)) / (len(data_submm_load_CCAT_250ghz_JJA_50) - 1)

data_submm_load_CCAT_250ghz_JJA_95 = tau_submm_load_CCAT_250ghz_JJA_95
data_sorted_submm_load_CCAT_250ghz_JJA_95 = np.sort(data_submm_load_CCAT_250ghz_JJA_95)
p_submm_load_CCAT_250ghz_JJA_95 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_JJA_95)) / (len(data_submm_load_CCAT_250ghz_JJA_95) - 1)

# calculating the cumulative fraction as a fuction of the optical depth/opacity tau
#-------------------------------------------------------------------------------------------SON-----------------------------------------------------------

data_submm_load_CCAT_250ghz_SON_5 = tau_submm_load_CCAT_250ghz_SON_5
data_sorted_submm_load_CCAT_250ghz_SON_5 = np.sort(data_submm_load_CCAT_250ghz_SON_5)
p_submm_load_CCAT_250ghz_SON_5 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_SON_5)) / (len(data_submm_load_CCAT_250ghz_SON_5) - 1)

data_submm_load_CCAT_250ghz_SON_50 = tau_submm_load_CCAT_250ghz_SON_50
data_sorted_submm_load_CCAT_250ghz_SON_50 = np.sort(data_submm_load_CCAT_250ghz_SON_50)
p_submm_load_CCAT_250ghz_SON_50 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_SON_50)) / (len(data_submm_load_CCAT_250ghz_SON_50) - 1)

data_submm_load_CCAT_250ghz_SON_95 = tau_submm_load_CCAT_250ghz_SON_95
data_sorted_submm_load_CCAT_250ghz_SON_95 = np.sort(data_submm_load_CCAT_250ghz_SON_95)
p_submm_load_CCAT_250ghz_SON_95 = 1. * np.arange(len(data_submm_load_CCAT_250ghz_SON_95)) / (len(data_submm_load_CCAT_250ghz_SON_95) - 1)

# %%
fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("250 GHz Cumulative distributions of zenith optical depths (Alt= 5.6 Km| BW= 43 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(data_sorted_submm_load_CCAT_250ghz_annual_5,p_submm_load_CCAT_250ghz_annual_5 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(data_sorted_submm_load_CCAT_250ghz_annual_50,p_submm_load_CCAT_250ghz_annual_50 ,label ="$H_2O$: 50th percentile")
axs[0][0].plot(data_sorted_submm_load_CCAT_250ghz_annual_95,p_submm_load_CCAT_250ghz_annual_95 ,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(data_sorted_submm_load_CCAT_250ghz_DJF_5,p_submm_load_CCAT_250ghz_DJF_5 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(data_sorted_submm_load_CCAT_250ghz_DJF_50,p_submm_load_CCAT_250ghz_DJF_50 ,label="$H_2O$: 50th percentile")
axs[0][1].plot(data_sorted_submm_load_CCAT_250ghz_DJF_95,p_submm_load_CCAT_250ghz_DJF_95 ,label="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(data_sorted_submm_load_CCAT_250ghz_JFM_5,p_submm_load_CCAT_250ghz_JFM_5 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(data_sorted_submm_load_CCAT_250ghz_JFM_50,p_submm_load_CCAT_250ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
axs[0][2].plot(data_sorted_submm_load_CCAT_250ghz_JFM_95,p_submm_load_CCAT_250ghz_JFM_95 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(data_sorted_submm_load_CCAT_250ghz_MAM_5,p_submm_load_CCAT_250ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(data_sorted_submm_load_CCAT_250ghz_MAM_50,p_submm_load_CCAT_250ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
axs[1][0].plot(data_sorted_submm_load_CCAT_250ghz_MAM_95,p_submm_load_CCAT_250ghz_MAM_95 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(data_sorted_submm_load_CCAT_250ghz_JJA_5,p_submm_load_CCAT_250ghz_JJA_5 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(data_sorted_submm_load_CCAT_250ghz_JJA_50,p_submm_load_CCAT_250ghz_JJA_50 ,label ="$H_2O$: 50th percentile")
axs[1][1].plot(data_sorted_submm_load_CCAT_250ghz_JJA_95,p_submm_load_CCAT_250ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(data_sorted_submm_load_CCAT_250ghz_SON_5,p_submm_load_CCAT_250ghz_SON_5 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(data_sorted_submm_load_CCAT_250ghz_SON_50,p_submm_load_CCAT_250ghz_SON_50 ,label ="$H_2O$: 50th percentile")
axs[1][2].plot(data_sorted_submm_load_CCAT_250ghz_SON_95,p_submm_load_CCAT_250ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading txer (pW) ",size=12)

fig.text(0.5, 0.04, r'Opacity ($ \tau $)', ha='center',size=15)
fig.text(0.07, 0.5, 'Cumulative Fraction', va='center', rotation='vertical',size=14)

plt.savefig("250ghz_outputs/250 GHz Cumulative distributions of zenith optical depths (Alt= 5.6 Km| BW= 43 GHz)_V1.jpg",dpi="figure")


plt.savefig("250ghz_outputs/250 GHz Cumulative distributions of zenith optical depths (Alt= 5.6 Km| BW= 43 GHz)_V1.jpg",dpi="figure")

plt.show()

# %%
# calculating the cumulative fraction as a fuction of the optical depth/opacity tau

#-------------------------------------------------------------------------------------------ANNUAL-----------------------------------------------------------

c_250ghz_annual_5, b_250ghz_annual_5= np.histogram(tau_submm_load_CCAT_250ghz_annual_5)
pdf_250ghz_annual_5 = c_250ghz_annual_5 / sum(c_250ghz_annual_5)
cdf_250ghz_annual_5 = np.cumsum(pdf_250ghz_annual_5)


c_250ghz_annual_50, b_250ghz_annual_50= np.histogram(tau_submm_load_CCAT_250ghz_annual_50)
pdf_250ghz_annual_50 = c_250ghz_annual_50 / sum(c_250ghz_annual_50)
cdf_250ghz_annual_50 = np.cumsum(pdf_250ghz_annual_50)

c_250ghz_annual_95, b_250ghz_annual_95= np.histogram(tau_submm_load_CCAT_250ghz_annual_95)
pdf_250ghz_annual_95 = c_250ghz_annual_95 / sum(c_250ghz_annual_95)
cdf_250ghz_annual_95 = np.cumsum(pdf_250ghz_annual_95)

#-------------------------------------------------------------------------------------------DJF-----------------------------------------------------------

c_250ghz_DJF_5, b_250ghz_DJF_5= np.histogram(tau_submm_load_CCAT_250ghz_DJF_5)
pdf_250ghz_DJF_5 = c_250ghz_DJF_5 / sum(c_250ghz_DJF_5)
cdf_250ghz_DJF_5 = np.cumsum(pdf_250ghz_DJF_5)
#plt.plot(cdf_250ghz_DJF_5)

c_250ghz_DJF_50, b_250ghz_DJF_50= np.histogram(tau_submm_load_CCAT_250ghz_DJF_50)
pdf_250ghz_DJF_50 = c_250ghz_DJF_50 / sum(c_250ghz_DJF_50)
cdf_250ghz_DJF_50 = np.cumsum(pdf_250ghz_DJF_50)

c_250ghz_DJF_95, b_250ghz_DJF_95= np.histogram(tau_submm_load_CCAT_250ghz_DJF_95)
pdf_250ghz_DJF_95 = c_250ghz_DJF_95 / sum(c_250ghz_DJF_95)
cdf_250ghz_DJF_95 = np.cumsum(pdf_250ghz_DJF_95)

#-------------------------------------------------------------------------------------------JFM-----------------------------------------------------------

c_250ghz_JFM_5, b_250ghz_JFM_5= np.histogram(tau_submm_load_CCAT_250ghz_JFM_5)
pdf_250ghz_JFM_5 = c_250ghz_JFM_5 / sum(c_250ghz_JFM_5)
cdf_250ghz_JFM_5 = np.cumsum(pdf_250ghz_JFM_5)
#plt.plot(cdf_250ghz_JFM_5)

c_250ghz_JFM_50, b_250ghz_JFM_50= np.histogram(tau_submm_load_CCAT_250ghz_JFM_50)
pdf_250ghz_JFM_50 = c_250ghz_JFM_50 / sum(c_250ghz_JFM_50)
cdf_250ghz_JFM_50 = np.cumsum(pdf_250ghz_JFM_50)

c_250ghz_JFM_95, b_250ghz_JFM_95= np.histogram(tau_submm_load_CCAT_250ghz_JFM_95)
pdf_250ghz_JFM_95 = c_250ghz_JFM_95 / sum(c_250ghz_JFM_95)
cdf_250ghz_JFM_95 = np.cumsum(pdf_250ghz_JFM_95)

#-------------------------------------------------------------------------------------------MAM-----------------------------------------------------------

c_250ghz_MAM_5, b_250ghz_MAM_5= np.histogram(tau_submm_load_CCAT_250ghz_MAM_5)
pdf_250ghz_MAM_5 = c_250ghz_MAM_5 / sum(c_250ghz_MAM_5)
cdf_250ghz_MAM_5 = np.cumsum(pdf_250ghz_MAM_5)
#plt.plot(cdf_250ghz_MAM_5)

c_250ghz_MAM_50, b_250ghz_MAM_50= np.histogram(tau_submm_load_CCAT_250ghz_MAM_50)
pdf_250ghz_MAM_50 = c_250ghz_MAM_50 / sum(c_250ghz_MAM_50)
cdf_250ghz_MAM_50 = np.cumsum(pdf_250ghz_MAM_50)

c_250ghz_MAM_95, b_250ghz_MAM_95= np.histogram(tau_submm_load_CCAT_250ghz_MAM_95)
pdf_250ghz_MAM_95 = c_250ghz_MAM_95 / sum(c_250ghz_MAM_95)
cdf_250ghz_MAM_95 = np.cumsum(pdf_250ghz_MAM_95)

#-------------------------------------------------------------------------------------------JJA-----------------------------------------------------------

c_250ghz_JJA_5, b_250ghz_JJA_5= np.histogram(tau_submm_load_CCAT_250ghz_JJA_5)
pdf_250ghz_JJA_5 = c_250ghz_JJA_5 / sum(c_250ghz_JJA_5)
cdf_250ghz_JJA_5 = np.cumsum(pdf_250ghz_JJA_5)
#plt.plot(cdf_250ghz_JJA_5)

c_250ghz_JJA_50, b_250ghz_JJA_50= np.histogram(tau_submm_load_CCAT_250ghz_JJA_50)
pdf_250ghz_JJA_50 = c_250ghz_JJA_50 / sum(c_250ghz_JJA_50)
cdf_250ghz_JJA_50 = np.cumsum(pdf_250ghz_JJA_50)

c_250ghz_JJA_95, b_250ghz_JJA_95= np.histogram(tau_submm_load_CCAT_250ghz_JJA_95)
pdf_250ghz_JJA_95 = c_250ghz_JJA_95 / sum(c_250ghz_JJA_95)
cdf_250ghz_JJA_95 = np.cumsum(pdf_250ghz_JJA_95)

#-------------------------------------------------------------------------------------------SON-----------------------------------------------------------

c_250ghz_SON_5, b_250ghz_SON_5= np.histogram(tau_submm_load_CCAT_250ghz_SON_5)
pdf_250ghz_SON_5 = c_250ghz_SON_5 / sum(c_250ghz_SON_5)
cdf_250ghz_SON_5 = np.cumsum(pdf_250ghz_SON_5)
#plt.plot(cdf_250ghz_SON_5)

c_250ghz_SON_50, b_250ghz_SON_50= np.histogram(tau_submm_load_CCAT_250ghz_SON_50)
pdf_250ghz_SON_50 = c_250ghz_SON_50 / sum(c_250ghz_SON_50)
cdf_250ghz_SON_50 = np.cumsum(pdf_250ghz_SON_50)

c_250ghz_SON_95, b_250ghz_SON_95= np.histogram(tau_submm_load_CCAT_250ghz_SON_95)
pdf_250ghz_SON_95 = c_250ghz_SON_95 / sum(c_250ghz_SON_95)
cdf_250ghz_SON_95 = np.cumsum(pdf_250ghz_SON_95)

# %%
fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("250 GHz Transmission vs Elevation Angle (Alt= 5.6 Km| BW= 43 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_5,tx_submm_load_CCAT_250ghz_annual_5 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_50,tx_submm_load_CCAT_250ghz_annual_50 ,label ="$H_2O$: 50th percentile")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_95,tx_submm_load_CCAT_250ghz_annual_95 ,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_5,tx_submm_load_CCAT_250ghz_DJF_5 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_50,tx_submm_load_CCAT_250ghz_DJF_50 ,label ="$H_2O$: 50th percentile")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_95,tx_submm_load_CCAT_250ghz_DJF_95 ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_5,tx_submm_load_CCAT_250ghz_JFM_5 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_50,tx_submm_load_CCAT_250ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_95,tx_submm_load_CCAT_250ghz_JFM_95 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_5,tx_submm_load_CCAT_250ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_50,tx_submm_load_CCAT_250ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_95,tx_submm_load_CCAT_250ghz_MAM_95 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_5,tx_submm_load_CCAT_250ghz_JJA_5 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_50,tx_submm_load_CCAT_250ghz_JJA_50 ,label ="$H_2O$: 50th percentile")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_95,tx_submm_load_CCAT_250ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_5,tx_submm_load_CCAT_250ghz_SON_5 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_50,tx_submm_load_CCAT_250ghz_SON_50 ,label ="$H_2O$: 50th percentile")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_95,tx_submm_load_CCAT_250ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading txer (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, 'Atmospheric Transmission', va='center', rotation='vertical',size=14)


plt.savefig("250ghz_outputs/250 GHz Transmission vs Elevation Angle (Alt= 5.6 Km| BW= 43 GHz)_V1.jpg",dpi="figure")

plt.show()

# %%
fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("250 GHz Brightness Temperature vs Elevation Angle (Alt= 5.6 Km| BW= 43 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_5,tb_submm_load_CCAT_250ghz_annual_5 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_50,tb_submm_load_CCAT_250ghz_annual_50 ,label ="$H_2O$: 50th percentile")
#axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_95,tb_submm_load_CCAT_250ghz_annual_95 ,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_5,tb_submm_load_CCAT_250ghz_DJF_5 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_50,tb_submm_load_CCAT_250ghz_DJF_50 ,label ="$H_2O$: 50th percentile")
#axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_95,tb_submm_load_CCAT_250ghz_DJF_95 ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_5,tb_submm_load_CCAT_250ghz_JFM_5 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_50,tb_submm_load_CCAT_250ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
#axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_95,tb_submm_load_CCAT_250ghz_JFM_95 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_5,tb_submm_load_CCAT_250ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_50,tb_submm_load_CCAT_250ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
#axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_95,tb_submm_load_CCAT_250ghz_MAM_95 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_5,tb_submm_load_CCAT_250ghz_JJA_5 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_50,tb_submm_load_CCAT_250ghz_JJA_50 ,label ="$H_2O$: 50th percentile")
#axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_95,tb_submm_load_CCAT_250ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_5,tb_submm_load_CCAT_250ghz_SON_5 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_50,tb_submm_load_CCAT_250ghz_SON_50 ,label ="$H_2O$: 50th percentile")
#axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_95,tb_submm_load_CCAT_250ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading tber (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, ' $ T_{b} $(K)', va='center', rotation='vertical',size=14)


plt.savefig("250ghz_outputs/250 GHz Brightness Temperature vs Elevation Angle (Alt= 5.6 Km| BW= 43 GHz)_V1.jpg",dpi="figure")

plt.show()

# %%
fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("250 GHz Rayleigh Jeans Temperature vs Elevation Angle (Alt= 5.6 Km| BW= 43 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_5,trj_submm_load_CCAT_250ghz_annual_5 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_50,trj_submm_load_CCAT_250ghz_annual_50 ,label ="$H_2O$: 50th percentile")
#axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_95,trj_submm_load_CCAT_250ghz_annual_95 ,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_5,trj_submm_load_CCAT_250ghz_DJF_5 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_50,trj_submm_load_CCAT_250ghz_DJF_50 ,label ="$H_2O$: 50th percentile")
#axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_95,trj_submm_load_CCAT_250ghz_DJF_95 ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_5,trj_submm_load_CCAT_250ghz_JFM_5 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_50,trj_submm_load_CCAT_250ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
#axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_95,trj_submm_load_CCAT_250ghz_JFM_95 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_5,trj_submm_load_CCAT_250ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_50,trj_submm_load_CCAT_250ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
#axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_95,trj_submm_load_CCAT_250ghz_MAM_95 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_5,trj_submm_load_CCAT_250ghz_JJA_5 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_50,trj_submm_load_CCAT_250ghz_JJA_50 ,label ="$H_2O$: 50th percentile")
#axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_95,trj_submm_load_CCAT_250ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_5,trj_submm_load_CCAT_250ghz_SON_5 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_50,trj_submm_load_CCAT_250ghz_SON_50 ,label ="$H_2O$: 50th percentile")
#axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_95,trj_submm_load_CCAT_250ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading trjer (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, ' $ T_{rj} $(K)', va='center', rotation='vertical',size=14)


plt.savefig("250ghz_outputs/250 GHz Rayleigh Jeans Temperature vs Elevation Angle (Alt= 5.6 Km| BW= 43 GHz)_V1.jpg",dpi="figure")

plt.show()

# %%
fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("250 GHz Detector Loading Power vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 43 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_5,pow_submm_load_CCAT_250ghz_annual_5 *1e12,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_50,pow_submm_load_CCAT_250ghz_annual_50 *1e12,label ="$H_2O$: 50th percentile")
#axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_95,pow_submm_load_CCAT_250ghz_annual_95 *1e12,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_5,pow_submm_load_CCAT_250ghz_DJF_5 *1e12,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_50,pow_submm_load_CCAT_250ghz_DJF_50 *1e12,label ="$H_2O$: 50th percentile")
#axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_95,pow_submm_load_CCAT_250ghz_DJF_95 *1e12,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_5,pow_submm_load_CCAT_250ghz_JFM_5 *1e12,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_50,pow_submm_load_CCAT_250ghz_JFM_50 *1e12,label ="$H_2O$: 50th percentile")
#axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_95,pow_submm_load_CCAT_250ghz_JFM_95 *1e12,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_5,pow_submm_load_CCAT_250ghz_MAM_5 *1e12,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_50,pow_submm_load_CCAT_250ghz_MAM_50 *1e12,label ="$H_2O$: 50th percentile")
#axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_95,pow_submm_load_CCAT_250ghz_MAM_95 *1e12,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_5,pow_submm_load_CCAT_250ghz_JJA_5 *1e12,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_50,pow_submm_load_CCAT_250ghz_JJA_50 *1e12,label ="$H_2O$: 50th percentile")
#axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_95,pow_submm_load_CCAT_250ghz_JJA_95 *1e12,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_5,pow_submm_load_CCAT_250ghz_SON_5 *1e12,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_50,pow_submm_load_CCAT_250ghz_SON_50 *1e12,label ="$H_2O$: 50th percentile")
#axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_95,pow_submm_load_CCAT_250ghz_SON_95 *1e12,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading Power (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, ' Loading Power (pW)', va='center', rotation='vertical',size=14)


plt.savefig("250ghz_outputs/250 GHz Detector Loading Power vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 43 GHz)_V1.jpg",dpi="figure")

plt.show()

# %% [markdown]
# ### Responsivity vs Power Plot
# ##### (Responsivity measures the input–output gain of a detector system)
#
# #### (based on the TiN CCAT 280 GHz first array)

# %%
# 850 GHz BLAST-TNG array

Qr = 36380  # Quality factor
Qc = 58290  # Coupling factor
f0 = 250e6 #[Hz]

# %%
responsivity_data = np.loadtxt("responsivity_meas.txt")
# power_mes = (res.power* 10**-12).to_numpy()  # watts
# respon= (res.Responsivity* 10**8).to_numpy() 
power_mes = responsivity_data[:,0] * 1e-12  # in W
respon = responsivity_data[:,1]*1e8

# plotting the data

plt.figure(figsize=(7,5))
plt.plot(power_mes* 1e12,respon)
plt.title("Responsivity vs Power (TiN CCAT 280 GHz array)",size=14)
plt.xlabel("Power(Pw)",size=14)
plt.ylabel("Responsivity",size=14)

plt.savefig("250ghz_outputs/Responsivity vs Power (TiN CCAT 280 GHz array)_V1.jpg",dpi="figure")
plt.show()

# %% [markdown]
# #### frequency shifts ~ power at the detector * responsivity

# %%
# ----------------------------------------------------------------------------------------ANNUAL--------------------------------------------------------------

freq_shift_submm_load_CCAT_250ghz_annual_5 = pow_submm_load_CCAT_250ghz_annual_5 * respon  
freq_shift_submm_load_CCAT_250ghz_annual_50 = pow_submm_load_CCAT_250ghz_annual_50 * respon
freq_shift_submm_load_CCAT_250ghz_annual_95 = pow_submm_load_CCAT_250ghz_annual_95 * respon

# ----------------------------------------------------------------------------------------DJF--------------------------------------------------------------

freq_shift_submm_load_CCAT_250ghz_DJF_5 = pow_submm_load_CCAT_250ghz_DJF_5 * respon  
freq_shift_submm_load_CCAT_250ghz_DJF_50 = pow_submm_load_CCAT_250ghz_DJF_50 * respon
freq_shift_submm_load_CCAT_250ghz_DJF_95 = pow_submm_load_CCAT_250ghz_DJF_95 * respon

# ----------------------------------------------------------------------------------------JFM--------------------------------------------------------------

freq_shift_submm_load_CCAT_250ghz_JFM_5 = pow_submm_load_CCAT_250ghz_JFM_5 * respon  
freq_shift_submm_load_CCAT_250ghz_JFM_50 = pow_submm_load_CCAT_250ghz_JFM_50 * respon
freq_shift_submm_load_CCAT_250ghz_JFM_95 = pow_submm_load_CCAT_250ghz_JFM_95 * respon

# ----------------------------------------------------------------------------------------MAM--------------------------------------------------------------

freq_shift_submm_load_CCAT_250ghz_MAM_5 = pow_submm_load_CCAT_250ghz_MAM_5 * respon  
freq_shift_submm_load_CCAT_250ghz_MAM_50 = pow_submm_load_CCAT_250ghz_MAM_50 * respon
freq_shift_submm_load_CCAT_250ghz_MAM_95 = pow_submm_load_CCAT_250ghz_MAM_95 * respon

# ----------------------------------------------------------------------------------------JJA--------------------------------------------------------------

freq_shift_submm_load_CCAT_250ghz_JJA_5 = pow_submm_load_CCAT_250ghz_JJA_5 * respon  
freq_shift_submm_load_CCAT_250ghz_JJA_50 = pow_submm_load_CCAT_250ghz_JJA_50 * respon
freq_shift_submm_load_CCAT_250ghz_JJA_95 = pow_submm_load_CCAT_250ghz_JJA_95 * respon

# ----------------------------------------------------------------------------------------SON--------------------------------------------------------------

freq_shift_submm_load_CCAT_250ghz_SON_5 = pow_submm_load_CCAT_250ghz_SON_5 * respon  
freq_shift_submm_load_CCAT_250ghz_SON_50 = pow_submm_load_CCAT_250ghz_SON_50 * respon
freq_shift_submm_load_CCAT_250ghz_SON_95 = pow_submm_load_CCAT_250ghz_SON_95 * respon

# %%
## plotting the freqeuncy shifts

fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("250 GHz Detector frequency shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 43 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_5,freq_shift_submm_load_CCAT_250ghz_annual_5 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_50,freq_shift_submm_load_CCAT_250ghz_annual_50 ,label ="$H_2O$: 50th percentile")
#axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_95,freq_shift_submm_load_CCAT_250ghz_annual_95 ,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_5,freq_shift_submm_load_CCAT_250ghz_DJF_5 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_50,freq_shift_submm_load_CCAT_250ghz_DJF_50 ,label ="$H_2O$: 50th percentile")
#axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_95,freq_shift_submm_load_CCAT_250ghz_DJF_95 ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_5,freq_shift_submm_load_CCAT_250ghz_JFM_5 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_50,freq_shift_submm_load_CCAT_250ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
#axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_95,freq_shift_submm_load_CCAT_250ghz_JFM_95 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_5,freq_shift_submm_load_CCAT_250ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_50,freq_shift_submm_load_CCAT_250ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
#axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_95,freq_shift_submm_load_CCAT_250ghz_MAM_95 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_5,freq_shift_submm_load_CCAT_250ghz_JJA_5 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_50,freq_shift_submm_load_CCAT_250ghz_JJA_50 ,label ="$H_2O$: 50th percentile")
#axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_95,freq_shift_submm_load_CCAT_250ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_5,freq_shift_submm_load_CCAT_250ghz_SON_5 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_50,freq_shift_submm_load_CCAT_250ghz_SON_50 ,label ="$H_2O$: 50th percentile")
#axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_95,freq_shift_submm_load_CCAT_250ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading freq_shifter (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, ' Loading frequency shift', va='center', rotation='vertical',size=14)


plt.savefig("250ghz_outputs/250 GHz Detector frequency shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 43 GHz)_V1.jpg",dpi="figure")

plt.show()

# %% [markdown]
# #### Actual Frequency Shift ~ Responsivity * Resonant Frequency * change in power (for 5 deg skydip)

# %%
fres = 800e6 # resonant freq in Hz(800 MHz)

# %%
ea_submm_load_CCAT_250ghz_annual_5
# Out:
# array([85., 80., 75., 70., 65., 60., 55., 50., 45., 40., 35., 30., 25.,
#        20., 15., 10.,  5.])

# %%
pow_submm_load_CCAT_250ghz_annual_5
# Out:
# array([4.43347675e-13, 4.48059022e-13, 4.56109614e-13, 4.67817007e-13,
#        4.83668313e-13, 5.04372914e-13, 5.30947419e-13, 5.64851913e-13,
#        6.08218639e-13, 6.64244540e-13, 7.37907759e-13, 8.37356488e-13,
#        9.76844454e-13, 1.18363951e-12, 1.51692337e-12, 2.13196067e-12,
#        3.58952708e-12])

# %%
ea_submm_load_CCAT_250ghz_annual_5
# Out:
# array([85., 80., 75., 70., 65., 60., 55., 50., 45., 40., 35., 30., 25.,
#        20., 15., 10.,  5.])

# %%
# difference in the frequency shifts at each elevation angle

# ----------------------------------------------------------------------------------------ANNUAL--------------------------------------------------------------

del_pow_submm_load_CCAT_250ghz_annual_5 = np.diff(pow_submm_load_CCAT_250ghz_annual_5)
del_pow_submm_load_CCAT_250ghz_annual_50 = np.diff(pow_submm_load_CCAT_250ghz_annual_50)
del_pow_submm_load_CCAT_250ghz_annual_95 = np.diff(pow_submm_load_CCAT_250ghz_annual_95)

# ----------------------------------------------------------------------------------------DJF--------------------------------------------------------------

del_pow_submm_load_CCAT_250ghz_DJF_5 = np.diff(pow_submm_load_CCAT_250ghz_DJF_5)
del_pow_submm_load_CCAT_250ghz_DJF_50 = np.diff(pow_submm_load_CCAT_250ghz_DJF_50)
del_pow_submm_load_CCAT_250ghz_DJF_95 = np.diff(pow_submm_load_CCAT_250ghz_DJF_95)

# ----------------------------------------------------------------------------------------JFM--------------------------------------------------------------

del_pow_submm_load_CCAT_250ghz_JFM_5 = np.diff(pow_submm_load_CCAT_250ghz_JFM_5)
del_pow_submm_load_CCAT_250ghz_JFM_50 = np.diff(pow_submm_load_CCAT_250ghz_JFM_50)
del_pow_submm_load_CCAT_250ghz_JFM_95 = np.diff(pow_submm_load_CCAT_250ghz_JFM_95)

# ----------------------------------------------------------------------------------------MAM--------------------------------------------------------------

del_pow_submm_load_CCAT_250ghz_MAM_5 = np.diff(pow_submm_load_CCAT_250ghz_MAM_5)
del_pow_submm_load_CCAT_250ghz_MAM_50 = np.diff(pow_submm_load_CCAT_250ghz_MAM_50)
del_pow_submm_load_CCAT_250ghz_MAM_95 = np.diff(pow_submm_load_CCAT_250ghz_MAM_95)

# ----------------------------------------------------------------------------------------JJA--------------------------------------------------------------

del_pow_submm_load_CCAT_250ghz_JJA_5 = np.diff(pow_submm_load_CCAT_250ghz_JJA_5)
del_pow_submm_load_CCAT_250ghz_JJA_50 = np.diff(pow_submm_load_CCAT_250ghz_JJA_50)
del_pow_submm_load_CCAT_250ghz_JJA_95 = np.diff(pow_submm_load_CCAT_250ghz_JJA_95)

# ----------------------------------------------------------------------------------------SON--------------------------------------------------------------

del_pow_submm_load_CCAT_250ghz_SON_5 = np.diff(pow_submm_load_CCAT_250ghz_SON_5)
del_pow_submm_load_CCAT_250ghz_SON_50 = np.diff(pow_submm_load_CCAT_250ghz_SON_50)
del_pow_submm_load_CCAT_250ghz_SON_95 = np.diff(pow_submm_load_CCAT_250ghz_SON_95)

# %% [markdown]
# #### Actual Frequency Shift ~ Responsivity * Resonant Frequency * change in power (for 5 deg skydip)

# %%
# calculating the actual frequency shifts

act_freq_shift_submm_load_CCAT_250ghz_annual_5 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_annual_5 )
act_freq_shift_submm_load_CCAT_250ghz_annual_50 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_annual_50 )
act_freq_shift_submm_load_CCAT_250ghz_annual_95 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_annual_95 )

act_freq_shift_submm_load_CCAT_250ghz_DJF_5 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_DJF_5 )
act_freq_shift_submm_load_CCAT_250ghz_DJF_50 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_DJF_50 )
act_freq_shift_submm_load_CCAT_250ghz_DJF_95 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_DJF_95 )

act_freq_shift_submm_load_CCAT_250ghz_JFM_5 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_JFM_5 )
act_freq_shift_submm_load_CCAT_250ghz_JFM_50 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_JFM_50 )
act_freq_shift_submm_load_CCAT_250ghz_JFM_95 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_JFM_95 )

act_freq_shift_submm_load_CCAT_250ghz_MAM_5 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_MAM_5 )
act_freq_shift_submm_load_CCAT_250ghz_MAM_50 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_MAM_50 )
act_freq_shift_submm_load_CCAT_250ghz_MAM_95 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_MAM_95 )

act_freq_shift_submm_load_CCAT_250ghz_JJA_5 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_JJA_5 )
act_freq_shift_submm_load_CCAT_250ghz_JJA_50 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_JJA_50 )
act_freq_shift_submm_load_CCAT_250ghz_JJA_95 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_JJA_95 )

act_freq_shift_submm_load_CCAT_250ghz_SON_5 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_SON_5 )
act_freq_shift_submm_load_CCAT_250ghz_SON_50 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_SON_50 )
act_freq_shift_submm_load_CCAT_250ghz_SON_95 = np.abs(respon[0:16] * fres *del_pow_submm_load_CCAT_250ghz_SON_95 )

# %%
## plotting the freqeuncy shifts

fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("250 GHz Actual detector frequency shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 43 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_5[0:16],act_freq_shift_submm_load_CCAT_250ghz_annual_5 *1e-6 ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_50[0:16],act_freq_shift_submm_load_CCAT_250ghz_annual_50 *1e-6 ,label ="$H_2O$: 50th percentile")
#axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_95[0:16],act_freq_shift_submm_load_CCAT_250ghz_annual_95 *1e-6,label ="$H_2O$: 95th percentile")
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_5[0:16],act_freq_shift_submm_load_CCAT_250ghz_DJF_5 *1e-6 ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_50[0:16],act_freq_shift_submm_load_CCAT_250ghz_DJF_50 *1e-6 ,label ="$H_2O$: 50th percentile")
#axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_95[0:16],act_freq_shift_submm_load_CCAT_250ghz_DJF_95 *1e-6 ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_5[0:16],act_freq_shift_submm_load_CCAT_250ghz_JFM_5 *1e-6 ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_50[0:16],act_freq_shift_submm_load_CCAT_250ghz_JFM_50 *1e-6,label ="$H_2O$: 50th percentile")
#axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_95[0:16],act_freq_shift_submm_load_CCAT_250ghz_JFM_95 *1e-6 ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_5[0:16],act_freq_shift_submm_load_CCAT_250ghz_MAM_5 *1e-6,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_50[0:16],act_freq_shift_submm_load_CCAT_250ghz_MAM_50 *1e-6,label ="$H_2O$: 50th percentile")
#axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_95[0:16],act_freq_shift_submm_load_CCAT_250ghz_MAM_95 *1e-6 ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_5[0:16],act_freq_shift_submm_load_CCAT_250ghz_JJA_5 *1e-6 ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_50[0:16],act_freq_shift_submm_load_CCAT_250ghz_JJA_50 *1e-6 ,label ="$H_2O$: 50th percentile")
#axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_95[0:16],act_freq_shift_submm_load_CCAT_250ghz_JJA_95 *1e-6,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_5[0:16],act_freq_shift_submm_load_CCAT_250ghz_SON_5 *1e-6 ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_50[0:16],act_freq_shift_submm_load_CCAT_250ghz_SON_50 *1e-6,label ="$H_2O$: 50th percentile")
#axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_95[0:16],act_freq_shift_submm_load_CCAT_250ghz_SON_95 *1e-6,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading act_freq_shifter (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, ' Actual frequency shift (MHz)', va='center', rotation='vertical',size=14)


plt.savefig("250ghz_outputs/250 GHz Actual detector frequency shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 43 GHz)_V1.jpg",dpi="figure")

plt.show()

# %%
act_freq_shift_submm_load_CCAT_250ghz_annual_5
# Out:
# array([   891.17491711,   1434.71825314,   1965.98810328,   2571.66962307,
#          3236.71435664,   4032.21666675,   5025.69712862,   6247.97216667,
#          7838.85789451,  10097.0106861 ,  13370.2619958 ,  18417.49920099,
#         26806.67398479,  42401.00008511,  76361.83424456, 179692.6865064 ])

# %%
act_freq_shift_submm_load_CCAT_250ghz_annual_5[1] - act_freq_shift_submm_load_CCAT_250ghz_annual_5[0]
# Out:
# 543.5433360360348

# %%
ea_submm_load_CCAT_250ghz_annual_5
# Out:
# array([85., 80., 75., 70., 65., 60., 55., 50., 45., 40., 35., 30., 25.,
#        20., 15., 10.,  5.])

# %%
# ---------------------------------------------------------------------------deg shift gradient -----------------------------------------------------------------------------

deg_shifts_submm_load_CCAT_250ghz_annual_5 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_annual_5  # this amount of deg shift for a change in 2.2 KHz or 1/10 the line width of 22000 Hz
deg_shifts_submm_load_CCAT_250ghz_annual_50 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_annual_50
deg_shifts_submm_load_CCAT_250ghz_annual_95 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_annual_95

deg_shifts_submm_load_CCAT_250ghz_DJF_5 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_DJF_5  # this amount of deg shift for a change in 2.2 KHz or 1/10 the line width of 22000 Hz
deg_shifts_submm_load_CCAT_250ghz_DJF_50 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_DJF_50
deg_shifts_submm_load_CCAT_250ghz_DJF_95 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_DJF_95

deg_shifts_submm_load_CCAT_250ghz_JFM_5 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_JFM_5  # this amount of deg shift for a change in 2.2 KHz or 1/10 the line width of 22000 Hz
deg_shifts_submm_load_CCAT_250ghz_JFM_50 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_JFM_50
deg_shifts_submm_load_CCAT_250ghz_JFM_95 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_JFM_95

deg_shifts_submm_load_CCAT_250ghz_MAM_5 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_MAM_5  # this amount of deg shift for a change in 2.2 KHz or 1/10 the line width of 22000 Hz
deg_shifts_submm_load_CCAT_250ghz_MAM_50 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_MAM_50
deg_shifts_submm_load_CCAT_250ghz_MAM_95 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_MAM_95

deg_shifts_submm_load_CCAT_250ghz_JJA_5 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_JJA_5  # this amount of deg shift for a change in 2.2 KHz or 1/10 the line width of 22000 Hz
deg_shifts_submm_load_CCAT_250ghz_JJA_50 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_JJA_50
deg_shifts_submm_load_CCAT_250ghz_JJA_95 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_JJA_95

deg_shifts_submm_load_CCAT_250ghz_SON_5 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_SON_5  # this amount of deg shift for a change in 2.2 KHz or 1/10 the line width of 22000 Hz
deg_shifts_submm_load_CCAT_250ghz_SON_50 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_SON_50
deg_shifts_submm_load_CCAT_250ghz_SON_95 = (2200*5)/act_freq_shift_submm_load_CCAT_250ghz_SON_95

# %%
plt.plot(ea_submm_load_CCAT_250ghz_annual_50[0:16],deg_shifts_submm_load_CCAT_250ghz_annual_50)
#plt.title("Change in elevation (deg) to get a 2.2 KHz frequency shift")
plt.ylabel("Change in Elevation for a 2.2 KHz freq shift (deg)")
plt.xlabel("Elevation angle (deg)")
plt.yticks(np.arange(min(deg_shifts_submm_load_CCAT_250ghz_annual_50), max(deg_shifts_submm_load_CCAT_250ghz_annual_50), 0.1))
plt.show()

# %%
## plotting the freqeuncy shifts

fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
fig.suptitle("250 GHz : Change in Elevation angle (deg) for a 2.2 KHz shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 43 GHz)",size=13)

axs[0][0].set_title("Annual")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_5[0:16],deg_shifts_submm_load_CCAT_250ghz_annual_5  ,label ="$H_2O$: 5th percentile")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_50[0:16],deg_shifts_submm_load_CCAT_250ghz_annual_50  ,label ="$H_2O$: 50th percentile")
axs[0][0].plot(ea_submm_load_CCAT_250ghz_annual_95[0:16],deg_shifts_submm_load_CCAT_250ghz_annual_95 ,label ="$H_2O$: 95th percentile")
#axs[0][0].yticks(np.arange(min(deg_shifts_submm_load_CCAT_250ghz_annual_50), max(deg_shifts_submm_load_CCAT_250ghz_annual_50), 0.1))
axs[0][0].legend()

axs[0][1].set_title("Dec, Jan, Feb")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_5[0:16],deg_shifts_submm_load_CCAT_250ghz_DJF_5  ,label ="$H_2O$: 5th percentile")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_50[0:16],deg_shifts_submm_load_CCAT_250ghz_DJF_50  ,label ="$H_2O$: 50th percentile")
axs[0][1].plot(ea_submm_load_CCAT_250ghz_DJF_95[0:16],deg_shifts_submm_load_CCAT_250ghz_DJF_95  ,label ="$H_2O$: 95th percentile")
axs[0][1].legend()

axs[0][2].set_title("Jan, Feb, Mar")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_5[0:16],deg_shifts_submm_load_CCAT_250ghz_JFM_5  ,label ="$H_2O$: 5th percentile")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_50[0:16],deg_shifts_submm_load_CCAT_250ghz_JFM_50 ,label ="$H_2O$: 50th percentile")
axs[0][2].plot(ea_submm_load_CCAT_250ghz_JFM_95[0:16],deg_shifts_submm_load_CCAT_250ghz_JFM_95  ,label ="$H_2O$: 95th percentile")
axs[0][2].legend()

axs[1][0].set_title("Mar, Apr, May")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_5[0:16],deg_shifts_submm_load_CCAT_250ghz_MAM_5 ,label ="$H_2O$: 5th percentile")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_50[0:16],deg_shifts_submm_load_CCAT_250ghz_MAM_50 ,label ="$H_2O$: 50th percentile")
axs[1][0].plot(ea_submm_load_CCAT_250ghz_MAM_95[0:16],deg_shifts_submm_load_CCAT_250ghz_MAM_95  ,label ="$H_2O$: 95th percentile")
axs[1][0].legend()

axs[1][1].set_title("Jun, Jul, Aug")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_5[0:16],deg_shifts_submm_load_CCAT_250ghz_JJA_5  ,label ="$H_2O$: 5th percentile")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_50[0:16],deg_shifts_submm_load_CCAT_250ghz_JJA_50  ,label ="$H_2O$: 50th percentile")
axs[1][1].plot(ea_submm_load_CCAT_250ghz_JJA_95[0:16],deg_shifts_submm_load_CCAT_250ghz_JJA_95 ,label ="$H_2O$: 95th percentile")
axs[1][1].legend()

axs[1][2].set_title("Sep, Oct, Nov")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_5[0:16],deg_shifts_submm_load_CCAT_250ghz_SON_5  ,label ="$H_2O$: 5th percentile")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_50[0:16],deg_shifts_submm_load_CCAT_250ghz_SON_50 ,label ="$H_2O$: 50th percentile")
axs[1][2].plot(ea_submm_load_CCAT_250ghz_SON_95[0:16],deg_shifts_submm_load_CCAT_250ghz_SON_95 ,label ="$H_2O$: 95th percentile")
axs[1][2].legend()

# plt.xlabel("Elevation Angle (dgrees)",size=12)
# plt.ylabel("Loading act_freq_shifter (pW) ",size=12)

fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
fig.text(0.07, 0.5, 'Change in Elevation for a 2.2 KHz freq shift (deg)', va='center', rotation='vertical',size=14)


plt.savefig("250ghz_outputs/250 GHz : Change in Elevation angle (deg) for a 2.2 KHz shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 43 GHz)_V1.jpg",dpi="figure")

plt.show()

# %% [markdown]
# ### FWHM = $ \frac{f_{res}}{Q_r} = \frac{800 MHz}{36380} = 22,000  Hz $
#
# ### $\frac{1}{10}$ of the Line width = $ 2.2 KHz $  (Linear Regime)

# %%
# ea_CCAT = 90-np.linspace(5.0,85.0,17)

# #----------------------------------------------------------------------ANNUAL------------------------------------------------------------------------

# #  5654th index corresponds to the 856.54 GHz or 250 GHz

# trj_CCAT_annual_5=[]
# tb_CCAT_annual_5=[]

# trj_CCAT_annual_50=[]
# tb_CCAT_annual_50=[]

# trj_CCAT_annual_95=[]
# tb_CCAT_annual_95=[]

# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_annual_5_skydip = np.loadtxt("CCAT_annual_5_skydip_"+ str(i) + ".out")
#     #f_CCAT_annual_5_skydip_5 = CCAT_annual_5_skydip_5[:,0][5654]
#     trj_CCAT_annual_5_skydip = CCAT_annual_5_skydip[:,3][5654]
#     tb_CCAT_annual_5_skydip = CCAT_annual_5_skydip[:,4][5654]
    
#     trj_CCAT_annual_5.append(trj_CCAT_annual_5_skydip)
#     tb_CCAT_annual_5.append(tb_CCAT_annual_5_skydip)


# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_annual_50_skydip = np.loadtxt("CCAT_annual_50_skydip_"+ str(i) + ".out")
#     #f_CCAT_annual_5_skydip_5 = CCAT_annual_5_skydip_5[:,0][5654]
#     trj_CCAT_annual_50_skydip = CCAT_annual_50_skydip[:,3][5654]
#     tb_CCAT_annual_50_skydip = CCAT_annual_50_skydip[:,4][5654]
    
#     trj_CCAT_annual_50.append(trj_CCAT_annual_50_skydip)
#     tb_CCAT_annual_50.append(tb_CCAT_annual_50_skydip)


# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_annual_95_skydip = np.loadtxt("CCAT_annual_95_skydip_"+ str(i) + ".out")
#     #f_CCAT_annual_5_skydip_5 = CCAT_annual_5_skydip_5[:,0][5654]
#     trj_CCAT_annual_95_skydip = CCAT_annual_95_skydip[:,3][5654]
#     tb_CCAT_annual_95_skydip = CCAT_annual_95_skydip[:,4][5654]
    
#     trj_CCAT_annual_95.append(trj_CCAT_annual_95_skydip)
#     tb_CCAT_annual_95.append(tb_CCAT_annual_95_skydip)

# #----------------------------------------------------------------------DJF------------------------------------------------------------------------

# #  5654th index corresponds to the 856.54 GHz or 250 GHz

# trj_CCAT_DJF_5=[]
# tb_CCAT_DJF_5=[]

# trj_CCAT_DJF_50=[]
# tb_CCAT_DJF_50=[]

# trj_CCAT_DJF_95=[]
# tb_CCAT_DJF_95=[]

# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_DJF_5_skydip = np.loadtxt("CCAT_DJF_5_skydip_"+ str(i) + ".out")
#     #f_CCAT_DJF_5_skydip_5 = CCAT_DJF_5_skydip_5[:,0][5654]
#     trj_CCAT_DJF_5_skydip = CCAT_DJF_5_skydip[:,3][5654]
#     tb_CCAT_DJF_5_skydip = CCAT_DJF_5_skydip[:,4][5654]
    
#     trj_CCAT_DJF_5.append(trj_CCAT_DJF_5_skydip)
#     tb_CCAT_DJF_5.append(tb_CCAT_DJF_5_skydip)


# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_DJF_50_skydip = np.loadtxt("CCAT_DJF_50_skydip_"+ str(i) + ".out")
#     #f_CCAT_DJF_5_skydip_5 = CCAT_DJF_5_skydip_5[:,0][5654]
#     trj_CCAT_DJF_50_skydip = CCAT_DJF_50_skydip[:,3][5654]
#     tb_CCAT_DJF_50_skydip = CCAT_DJF_50_skydip[:,4][5654]
    
#     trj_CCAT_DJF_50.append(trj_CCAT_DJF_50_skydip)
#     tb_CCAT_DJF_50.append(tb_CCAT_DJF_50_skydip)


# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_DJF_95_skydip = np.loadtxt("CCAT_DJF_95_skydip_"+ str(i) + ".out")
#     #f_CCAT_DJF_5_skydip_5 = CCAT_DJF_5_skydip_5[:,0][5654]
#     trj_CCAT_DJF_95_skydip = CCAT_DJF_95_skydip[:,3][5654]
#     tb_CCAT_DJF_95_skydip = CCAT_DJF_95_skydip[:,4][5654]
    
#     trj_CCAT_DJF_95.append(trj_CCAT_DJF_95_skydip)
#     tb_CCAT_DJF_95.append(tb_CCAT_DJF_95_skydip)

# #----------------------------------------------------------------------JFM------------------------------------------------------------------------

# #  5654th index corresponds to the 856.54 GHz or 250 GHz

# trj_CCAT_JFM_5=[]
# tb_CCAT_JFM_5=[]

# trj_CCAT_JFM_50=[]
# tb_CCAT_JFM_50=[]

# trj_CCAT_JFM_95=[]
# tb_CCAT_JFM_95=[]

# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_JFM_5_skydip = np.loadtxt("CCAT_JFM_5_skydip_"+ str(i) + ".out")
#     #f_CCAT_JFM_5_skydip_5 = CCAT_JFM_5_skydip_5[:,0][5654]
#     trj_CCAT_JFM_5_skydip = CCAT_JFM_5_skydip[:,3][5654]
#     tb_CCAT_JFM_5_skydip = CCAT_JFM_5_skydip[:,4][5654]
    
#     trj_CCAT_JFM_5.append(trj_CCAT_JFM_5_skydip)
#     tb_CCAT_JFM_5.append(tb_CCAT_JFM_5_skydip)


# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_JFM_50_skydip = np.loadtxt("CCAT_JFM_50_skydip_"+ str(i) + ".out")
#     #f_CCAT_JFM_5_skydip_5 = CCAT_JFM_5_skydip_5[:,0][5654]
#     trj_CCAT_JFM_50_skydip = CCAT_JFM_50_skydip[:,3][5654]
#     tb_CCAT_JFM_50_skydip = CCAT_JFM_50_skydip[:,4][5654]
    
#     trj_CCAT_JFM_50.append(trj_CCAT_JFM_50_skydip)
#     tb_CCAT_JFM_50.append(tb_CCAT_JFM_50_skydip)


# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_JFM_95_skydip = np.loadtxt("CCAT_JFM_95_skydip_"+ str(i) + ".out")
#     #f_CCAT_JFM_5_skydip_5 = CCAT_JFM_5_skydip_5[:,0][5654]
#     trj_CCAT_JFM_95_skydip = CCAT_JFM_95_skydip[:,3][5654]
#     tb_CCAT_JFM_95_skydip = CCAT_JFM_95_skydip[:,4][5654]
    
#     trj_CCAT_JFM_95.append(trj_CCAT_JFM_95_skydip)
#     tb_CCAT_JFM_95.append(tb_CCAT_JFM_95_skydip)

# #----------------------------------------------------------------------MAM------------------------------------------------------------------------

# #  5654th index corresponds to the 856.54 GHz or 250 GHz

# trj_CCAT_MAM_5=[]
# tb_CCAT_MAM_5=[]

# trj_CCAT_MAM_50=[]
# tb_CCAT_MAM_50=[]

# trj_CCAT_MAM_95=[]
# tb_CCAT_MAM_95=[]

# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_MAM_5_skydip = np.loadtxt("CCAT_MAM_5_skydip_"+ str(i) + ".out")
#     #f_CCAT_MAM_5_skydip_5 = CCAT_MAM_5_skydip_5[:,0][5654]
#     trj_CCAT_MAM_5_skydip = CCAT_MAM_5_skydip[:,3][5654]
#     tb_CCAT_MAM_5_skydip = CCAT_MAM_5_skydip[:,4][5654]
    
#     trj_CCAT_MAM_5.append(trj_CCAT_MAM_5_skydip)
#     tb_CCAT_MAM_5.append(tb_CCAT_MAM_5_skydip)


# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_MAM_50_skydip = np.loadtxt("CCAT_MAM_50_skydip_"+ str(i) + ".out")
#     #f_CCAT_MAM_5_skydip_5 = CCAT_MAM_5_skydip_5[:,0][5654]
#     trj_CCAT_MAM_50_skydip = CCAT_MAM_50_skydip[:,3][5654]
#     tb_CCAT_MAM_50_skydip = CCAT_MAM_50_skydip[:,4][5654]
    
#     trj_CCAT_MAM_50.append(trj_CCAT_MAM_50_skydip)
#     tb_CCAT_MAM_50.append(tb_CCAT_MAM_50_skydip)


# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_MAM_95_skydip = np.loadtxt("CCAT_MAM_95_skydip_"+ str(i) + ".out")
#     #f_CCAT_MAM_5_skydip_5 = CCAT_MAM_5_skydip_5[:,0][5654]
#     trj_CCAT_MAM_95_skydip = CCAT_MAM_95_skydip[:,3][5654]
#     tb_CCAT_MAM_95_skydip = CCAT_MAM_95_skydip[:,4][5654]
    
#     trj_CCAT_MAM_95.append(trj_CCAT_MAM_95_skydip)
#     tb_CCAT_MAM_95.append(tb_CCAT_MAM_95_skydip)

# #----------------------------------------------------------------------JJA------------------------------------------------------------------------

# #  5654th index corresponds to the 856.54 GHz or 250 GHz

# trj_CCAT_JJA_5=[]
# tb_CCAT_JJA_5=[]

# trj_CCAT_JJA_50=[]
# tb_CCAT_JJA_50=[]

# trj_CCAT_JJA_95=[]
# tb_CCAT_JJA_95=[]

# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_JJA_5_skydip = np.loadtxt("CCAT_JJA_5_skydip_"+ str(i) + ".out")
#     #f_CCAT_JJA_5_skydip_5 = CCAT_JJA_5_skydip_5[:,0][5654]
#     trj_CCAT_JJA_5_skydip = CCAT_JJA_5_skydip[:,3][5654]
#     tb_CCAT_JJA_5_skydip = CCAT_JJA_5_skydip[:,4][5654]
    
#     trj_CCAT_JJA_5.append(trj_CCAT_JJA_5_skydip)
#     tb_CCAT_JJA_5.append(tb_CCAT_JJA_5_skydip)


# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_JJA_50_skydip = np.loadtxt("CCAT_JJA_50_skydip_"+ str(i) + ".out")
#     #f_CCAT_JJA_5_skydip_5 = CCAT_JJA_5_skydip_5[:,0][5654]
#     trj_CCAT_JJA_50_skydip = CCAT_JJA_50_skydip[:,3][5654]
#     tb_CCAT_JJA_50_skydip = CCAT_JJA_50_skydip[:,4][5654]
    
#     trj_CCAT_JJA_50.append(trj_CCAT_JJA_50_skydip)
#     tb_CCAT_JJA_50.append(tb_CCAT_JJA_50_skydip)


# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_JJA_95_skydip = np.loadtxt("CCAT_JJA_95_skydip_"+ str(i) + ".out")
#     #f_CCAT_JJA_5_skydip_5 = CCAT_JJA_5_skydip_5[:,0][5654]
#     trj_CCAT_JJA_95_skydip = CCAT_JJA_95_skydip[:,3][5654]
#     tb_CCAT_JJA_95_skydip = CCAT_JJA_95_skydip[:,4][5654]
    
#     trj_CCAT_JJA_95.append(trj_CCAT_JJA_95_skydip)
#     tb_CCAT_JJA_95.append(tb_CCAT_JJA_95_skydip)

# #----------------------------------------------------------------------SON------------------------------------------------------------------------

# #  5654th index corresponds to the 856.54 GHz or 250 GHz

# trj_CCAT_SON_5=[]
# tb_CCAT_SON_5=[]

# trj_CCAT_SON_50=[]
# tb_CCAT_SON_50=[]

# trj_CCAT_SON_95=[]
# tb_CCAT_SON_95=[]

# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_SON_5_skydip = np.loadtxt("CCAT_SON_5_skydip_"+ str(i) + ".out")
#     #f_CCAT_SON_5_skydip_5 = CCAT_SON_5_skydip_5[:,0][5654]
#     trj_CCAT_SON_5_skydip = CCAT_SON_5_skydip[:,3][5654]
#     tb_CCAT_SON_5_skydip = CCAT_SON_5_skydip[:,4][5654]
    
#     trj_CCAT_SON_5.append(trj_CCAT_SON_5_skydip)
#     tb_CCAT_SON_5.append(tb_CCAT_SON_5_skydip)


# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_SON_50_skydip = np.loadtxt("CCAT_SON_50_skydip_"+ str(i) + ".out")
#     #f_CCAT_SON_5_skydip_5 = CCAT_SON_5_skydip_5[:,0][5654]
#     trj_CCAT_SON_50_skydip = CCAT_SON_50_skydip[:,3][5654]
#     tb_CCAT_SON_50_skydip = CCAT_SON_50_skydip[:,4][5654]
    
#     trj_CCAT_SON_50.append(trj_CCAT_SON_50_skydip)
#     tb_CCAT_SON_50.append(tb_CCAT_SON_50_skydip)


# for i in np.linspace(5.0,85.0,17):
    
#     CCAT_SON_95_skydip = np.loadtxt("CCAT_SON_95_skydip_"+ str(i) + ".out")
#     #f_CCAT_SON_5_skydip_5 = CCAT_SON_5_skydip_5[:,0][5654]
#     trj_CCAT_SON_95_skydip = CCAT_SON_95_skydip[:,3][5654]
#     tb_CCAT_SON_95_skydip = CCAT_SON_95_skydip[:,4][5654]
    
#     trj_CCAT_SON_95.append(trj_CCAT_SON_95_skydip)
#     tb_CCAT_SON_95.append(tb_CCAT_SON_95_skydip)

# %%
# fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
# fig.suptitle("Site Files : Rayleigh Jeans Temperature vs Elevation Angle (Alt= 5.6 Km| BW= 43 GHz)",size=13)

# axs[0][0].set_title("Annual")
# axs[0][0].plot(ea_CCAT,trj_CCAT_annual_5 ,label ="$H_2O$: 5th percentile")
# axs[0][0].plot(ea_CCAT,trj_CCAT_annual_50 ,label ="$H_2O$: 50th percentile")
# #axs[0][0].plot(ea_CCAT,trj_CCAT_annual_95 ,label ="$H_2O$: 95th percentile")
# axs[0][0].legend()

# axs[0][1].set_title("Dec, Jan, Feb")
# axs[0][1].plot(ea_CCAT,trj_CCAT_DJF_5 ,label ="$H_2O$: 5th percentile")
# axs[0][1].plot(ea_CCAT,trj_CCAT_DJF_50 ,label ="$H_2O$: 50th percentile")
# #axs[0][1].plot(ea_CCAT,trj_CCAT_DJF_95 ,label ="$H_2O$: 95th percentile")
# axs[0][1].legend()

# axs[0][2].set_title("Jan, Feb, Mar")
# axs[0][2].plot(ea_CCAT,trj_CCAT_JFM_5 ,label ="$H_2O$: 5th percentile")
# axs[0][2].plot(ea_CCAT,trj_CCAT_JFM_50 ,label ="$H_2O$: 50th percentile")
# #axs[0][2].plot(ea_CCAT,trj_CCAT_JFM_95 ,label ="$H_2O$: 95th percentile")
# axs[0][2].legend()

# axs[1][0].set_title("Mar, Apr, May")
# axs[1][0].plot(ea_CCAT,trj_CCAT_MAM_5 ,label ="$H_2O$: 5th percentile")
# axs[1][0].plot(ea_CCAT,trj_CCAT_MAM_50 ,label ="$H_2O$: 50th percentile")
# #axs[1][0].plot(ea_CCAT,trj_CCAT_MAM_95 ,label ="$H_2O$: 95th percentile")
# axs[1][0].legend()

# axs[1][1].set_title("Jun, Jul, Aug")
# axs[1][1].plot(ea_CCAT,trj_CCAT_JJA_5 ,label ="$H_2O$: 5th percentile")
# axs[1][1].plot(ea_CCAT,trj_CCAT_JJA_50 ,label ="$H_2O$: 50th percentile")
# #axs[1][1].plot(ea_CCAT,trj_CCAT_JJA_95 ,label ="$H_2O$: 95th percentile")
# axs[1][1].legend()

# axs[1][2].set_title("Sep, Oct, Nov")
# axs[1][2].plot(ea_CCAT,trj_CCAT_SON_5 ,label ="$H_2O$: 5th percentile")
# axs[1][2].plot(ea_CCAT,trj_CCAT_SON_50 ,label ="$H_2O$: 50th percentile")
# #axs[1][2].plot(ea_CCAT,trj_CCAT_SON_95 ,label ="$H_2O$: 95th percentile")
# axs[1][2].legend()

# # plt.xlabel("Elevation Angle (dgrees)",size=12)
# # plt.ylabel("Loading trjer (pW) ",size=12)

# fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
# fig.text(0.07, 0.5, ' $ T_{rj} $(K)', va='center', rotation='vertical',size=14)


# plt.savefig("250ghz_outputs/Site Files: Rayleigh Jeans Temperature vs Elevation Angle (Alt= 5.6 Km| BW= 43 GHz)_V1.jpg",dpi="figure")

# plt.show()

# %%
# # power loading at the detectors in W

# #-------------------------------------------------------------------------------------------ANNUAL-----------------------------------------------------------

# pow_CCAT_annual_5 = eff * np.array(trj_CCAT_annual_5 ) * k * bw 
# pow_CCAT_annual_50 = eff * np.array(trj_CCAT_annual_50 ) * k * bw 
# pow_CCAT_annual_95 = eff * np.array(trj_CCAT_annual_95 ) * k * bw 

# #------------------------------------------------------------------------------------------DJF----------------------------------------------------------------
# pow_CCAT_DJF_5 = eff * np.array(trj_CCAT_DJF_5 ) * k * bw 
# pow_CCAT_DJF_50 = eff * np.array(trj_CCAT_DJF_50 ) * k * bw 
# pow_CCAT_DJF_95 = eff * np.array(trj_CCAT_DJF_95 ) * k * bw 

# #------------------------------------------------------------------------------------------JFM----------------------------------------------------------------
# pow_CCAT_JFM_5 = eff * np.array(trj_CCAT_JFM_5 ) * k * bw 
# pow_CCAT_JFM_50 = eff * np.array(trj_CCAT_JFM_50 ) * k * bw 
# pow_CCAT_JFM_95 = eff * np.array(trj_CCAT_JFM_95 ) * k * bw 

# #------------------------------------------------------------------------------------------MAM----------------------------------------------------------------
# pow_CCAT_MAM_5 = eff * np.array(trj_CCAT_MAM_5 ) * k * bw 
# pow_CCAT_MAM_50 = eff * np.array(trj_CCAT_MAM_50 ) * k * bw 
# pow_CCAT_MAM_95 = eff * np.array(trj_CCAT_MAM_95 ) * k * bw 

# #------------------------------------------------------------------------------------------JJA----------------------------------------------------------------
# pow_CCAT_JJA_5 = eff * np.array(trj_CCAT_JJA_5 ) * k * bw 
# pow_CCAT_JJA_50 = eff * np.array(trj_CCAT_JJA_50 ) * k * bw 
# pow_CCAT_JJA_95 = eff * np.array(trj_CCAT_JJA_95 ) * k * bw 

# #------------------------------------------------------------------------------------------SON----------------------------------------------------------------
# pow_CCAT_SON_5 = eff * np.array(trj_CCAT_SON_5 ) * k * bw 
# pow_CCAT_SON_50 = eff * np.array(trj_CCAT_SON_50 ) * k * bw 
# pow_CCAT_SON_95 = eff * np.array(trj_CCAT_SON_95 ) * k * bw

# %%
# fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
# fig.suptitle("Site Files : Power loading at detector vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $|BW= 43 GHz)",size=13)

# axs[0][0].set_title("Annual")
# axs[0][0].plot(ea_CCAT,pow_CCAT_annual_5 *1e12,label ="$H_2O$: 5th percentile")
# axs[0][0].plot(ea_CCAT,pow_CCAT_annual_50 *1e12,label ="$H_2O$: 50th percentile")
# #axs[0][0].plot(ea_CCAT,pow_CCAT_annual_95 *1e12,label ="$H_2O$: 95th percentile")
# axs[0][0].legend()

# axs[0][1].set_title("Dec, Jan, Feb")
# axs[0][1].plot(ea_CCAT,pow_CCAT_DJF_5 *1e12,label ="$H_2O$: 5th percentile")
# axs[0][1].plot(ea_CCAT,pow_CCAT_DJF_50 *1e12,label ="$H_2O$: 50th percentile")
# #axs[0][1].plot(ea_CCAT,pow_CCAT_DJF_95 *1e12,label ="$H_2O$: 95th percentile")
# axs[0][1].legend()

# axs[0][2].set_title("Jan, Feb, Mar")
# axs[0][2].plot(ea_CCAT,pow_CCAT_JFM_5 *1e12,label ="$H_2O$: 5th percentile")
# axs[0][2].plot(ea_CCAT,pow_CCAT_JFM_50 *1e12,label ="$H_2O$: 50th percentile")
# #axs[0][2].plot(ea_CCAT,pow_CCAT_JFM_95 *1e12,label ="$H_2O$: 95th percentile")
# axs[0][2].legend()

# axs[1][0].set_title("Mar, Apr, May")
# axs[1][0].plot(ea_CCAT,pow_CCAT_MAM_5 *1e12,label ="$H_2O$: 5th percentile")
# axs[1][0].plot(ea_CCAT,pow_CCAT_MAM_50 *1e12,label ="$H_2O$: 50th percentile")
# #axs[1][0].plot(ea_CCAT,pow_CCAT_MAM_95 *1e12,label ="$H_2O$: 95th percentile")
# axs[1][0].legend()

# axs[1][1].set_title("Jun, Jul, Aug")
# axs[1][1].plot(ea_CCAT,pow_CCAT_JJA_5 *1e12,label ="$H_2O$: 5th percentile")
# axs[1][1].plot(ea_CCAT,pow_CCAT_JJA_50 *1e12,label ="$H_2O$: 50th percentile")
# #axs[1][1].plot(ea_CCAT,pow_CCAT_JJA_95 *1e12,label ="$H_2O$: 95th percentile")
# axs[1][1].legend()

# axs[1][2].set_title("Sep, Oct, Nov")
# axs[1][2].plot(ea_CCAT,pow_CCAT_SON_5 *1e12,label ="$H_2O$: 5th percentile")
# axs[1][2].plot(ea_CCAT,pow_CCAT_SON_50 *1e12,label ="$H_2O$: 50th percentile")
# #axs[1][2].plot(ea_CCAT,pow_CCAT_SON_95 *1e12,label ="$H_2O$: 95th percentile")
# axs[1][2].legend()

# # plt.xlabel("Elevation Angle (dgrees)",size=12)
# # plt.ylabel("Loading power (pW) ",size=12)

# fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
# fig.text(0.07, 0.5, ' Power(pW)', va='center', rotation='vertical',size=14)


# plt.savefig("250ghz_outputs/Site Files: Power Loading vs Elevation Angle (Alt= 5.6 Km| BW= 43 GHz)_V1.jpg",dpi="figure")

# plt.show()

# %%
# fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
# fig.suptitle("Site Files : Brightness Temperature vs Elevation Angle (Alt= 5.6 Km| BW= 43 GHz)",size=13)

# axs[0][0].set_title("Annual")
# axs[0][0].plot(ea_CCAT,tb_CCAT_annual_5 ,label ="$H_2O$: 5th percentile")
# axs[0][0].plot(ea_CCAT,tb_CCAT_annual_50 ,label ="$H_2O$: 50th percentile")
# #axs[0][0].plot(ea_CCAT,tb_CCAT_annual_95 ,label ="$H_2O$: 95th percentile")
# axs[0][0].legend()

# axs[0][1].set_title("Dec, Jan, Feb")
# axs[0][1].plot(ea_CCAT,tb_CCAT_DJF_5 ,label ="$H_2O$: 5th percentile")
# axs[0][1].plot(ea_CCAT,tb_CCAT_DJF_50 ,label ="$H_2O$: 50th percentile")
# #axs[0][1].plot(ea_CCAT,tb_CCAT_DJF_95 ,label ="$H_2O$: 95th percentile")
# axs[0][1].legend()

# axs[0][2].set_title("Jan, Feb, Mar")
# axs[0][2].plot(ea_CCAT,tb_CCAT_JFM_5 ,label ="$H_2O$: 5th percentile")
# axs[0][2].plot(ea_CCAT,tb_CCAT_JFM_50 ,label ="$H_2O$: 50th percentile")
# #axs[0][2].plot(ea_CCAT,tb_CCAT_JFM_95 ,label ="$H_2O$: 95th percentile")
# axs[0][2].legend()

# axs[1][0].set_title("Mar, Apr, May")
# axs[1][0].plot(ea_CCAT,tb_CCAT_MAM_5 ,label ="$H_2O$: 5th percentile")
# axs[1][0].plot(ea_CCAT,tb_CCAT_MAM_50 ,label ="$H_2O$: 50th percentile")
# #axs[1][0].plot(ea_CCAT,tb_CCAT_MAM_95 ,label ="$H_2O$: 95th percentile")
# axs[1][0].legend()

# axs[1][1].set_title("Jun, Jul, Aug")
# axs[1][1].plot(ea_CCAT,tb_CCAT_JJA_5 ,label ="$H_2O$: 5th percentile")
# axs[1][1].plot(ea_CCAT,tb_CCAT_JJA_50 ,label ="$H_2O$: 50th percentile")
# #axs[1][1].plot(ea_CCAT,tb_CCAT_JJA_95 ,label ="$H_2O$: 95th percentile")
# axs[1][1].legend()

# axs[1][2].set_title("Sep, Oct, Nov")
# axs[1][2].plot(ea_CCAT,tb_CCAT_SON_5 ,label ="$H_2O$: 5th percentile")
# axs[1][2].plot(ea_CCAT,tb_CCAT_SON_50 ,label ="$H_2O$: 50th percentile")
# #axs[1][2].plot(ea_CCAT,tb_CCAT_SON_95 ,label ="$H_2O$: 95th percentile")
# axs[1][2].legend()

# # plt.xlabel("Elevation Angle (dgrees)",size=12)
# # plt.ylabel("Loading tber (pW) ",size=12)

# fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
# fig.text(0.07, 0.5, ' $ T_{rj} $(K)', va='center', rotation='vertical',size=14)


# plt.savefig("250ghz_outputs/Site Files: Brightness Temperature vs Elevation Angle (Alt= 5.6 Km| BW= 43 GHz)_V1.jpg",dpi="figure")

# plt.show()

# %%
pow_CCAT_JJA_95
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29218/3231998659.py in <module>
# ----> 1 pow_CCAT_JJA_95
#
# NameError: name 'pow_CCAT_JJA_95' is not defined

# %%
# # difference in the frequency shifts at each elevation angle

# # ----------------------------------------------------------------------------------------ANNUAL--------------------------------------------------------------

# del_pow_CCAT_annual_5 = np.diff(pow_CCAT_annual_5)
# del_pow_CCAT_annual_50 = np.diff(pow_CCAT_annual_50)
# del_pow_CCAT_annual_95 = np.diff(pow_CCAT_annual_95)

# # ----------------------------------------------------------------------------------------DJF--------------------------------------------------------------

# del_pow_CCAT_DJF_5 = np.diff(pow_CCAT_DJF_5)
# del_pow_CCAT_DJF_50 = np.diff(pow_CCAT_DJF_50)
# del_pow_CCAT_DJF_95 = np.diff(pow_CCAT_DJF_95)

# # ----------------------------------------------------------------------------------------JFM--------------------------------------------------------------

# del_pow_CCAT_JFM_5 = np.diff(pow_CCAT_JFM_5)
# del_pow_CCAT_JFM_50 = np.diff(pow_CCAT_JFM_50)
# del_pow_CCAT_JFM_95 = np.diff(pow_CCAT_JFM_95)

# # ----------------------------------------------------------------------------------------MAM--------------------------------------------------------------

# del_pow_CCAT_MAM_5 = np.diff(pow_CCAT_MAM_5)
# del_pow_CCAT_MAM_50 = np.diff(pow_CCAT_MAM_50)
# del_pow_CCAT_MAM_95 = np.diff(pow_CCAT_MAM_95)

# # ----------------------------------------------------------------------------------------JJA--------------------------------------------------------------

# del_pow_CCAT_JJA_5 = np.diff(pow_CCAT_JJA_5)
# del_pow_CCAT_JJA_50 = np.diff(pow_CCAT_JJA_50)
# del_pow_CCAT_JJA_95 = np.diff(pow_CCAT_JJA_95)

# # ----------------------------------------------------------------------------------------SON--------------------------------------------------------------

# del_pow_CCAT_SON_5 = np.diff(pow_CCAT_SON_5)
# del_pow_CCAT_SON_50 = np.diff(pow_CCAT_SON_50)
# del_pow_CCAT_SON_95 = np.diff(pow_CCAT_SON_95)

# %% [markdown]
# #### Actual Frequency Shift ~ Responsivity * Resonant Frequency * change in power (for 5 deg skydip)

# %%
# # calculating the actual frequency shifts

# act_freq_shift_CCAT_annual_5 = np.abs(respon[0:16] * fres *del_pow_CCAT_annual_5 )
# act_freq_shift_CCAT_annual_50 = np.abs(respon[0:16] * fres *del_pow_CCAT_annual_50 )
# act_freq_shift_CCAT_annual_95 = np.abs(respon[0:16] * fres *del_pow_CCAT_annual_95 )

# act_freq_shift_CCAT_DJF_5 = np.abs(respon[0:16] * fres *del_pow_CCAT_DJF_5 )
# act_freq_shift_CCAT_DJF_50 = np.abs(respon[0:16] * fres *del_pow_CCAT_DJF_50 )
# act_freq_shift_CCAT_DJF_95 = np.abs(respon[0:16] * fres *del_pow_CCAT_DJF_95 )

# act_freq_shift_CCAT_JFM_5 = np.abs(respon[0:16] * fres *del_pow_CCAT_JFM_5 )
# act_freq_shift_CCAT_JFM_50 = np.abs(respon[0:16] * fres *del_pow_CCAT_JFM_50 )
# act_freq_shift_CCAT_JFM_95 = np.abs(respon[0:16] * fres *del_pow_CCAT_JFM_95 )

# act_freq_shift_CCAT_MAM_5 = np.abs(respon[0:16] * fres *del_pow_CCAT_MAM_5 )
# act_freq_shift_CCAT_MAM_50 = np.abs(respon[0:16] * fres *del_pow_CCAT_MAM_50 )
# act_freq_shift_CCAT_MAM_95 = np.abs(respon[0:16] * fres *del_pow_CCAT_MAM_95 )

# act_freq_shift_CCAT_JJA_5 = np.abs(respon[0:16] * fres *del_pow_CCAT_JJA_5 )
# act_freq_shift_CCAT_JJA_50 = np.abs(respon[0:16] * fres *del_pow_CCAT_JJA_50 )
# act_freq_shift_CCAT_JJA_95 = np.abs(respon[0:16] * fres *del_pow_CCAT_JJA_95 )

# act_freq_shift_CCAT_SON_5 = np.abs(respon[0:16] * fres *del_pow_CCAT_SON_5 )
# act_freq_shift_CCAT_SON_50 = np.abs(respon[0:16] * fres *del_pow_CCAT_SON_50 )
# act_freq_shift_CCAT_SON_95 = np.abs(respon[0:16] * fres *del_pow_CCAT_SON_95 )

# %%
# ## plotting the freqeuncy shifts

# fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
# fig.suptitle("Site Files : 250 GHz Actual detector frequency shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 43 GHz)",size=13)

# axs[0][0].set_title("Annual")
# axs[0][0].plot(ea_CCAT[0:16],act_freq_shift_CCAT_annual_5 *1e-6 ,label ="$H_2O$: 5th percentile")
# axs[0][0].plot(ea_CCAT[0:16],act_freq_shift_CCAT_annual_50 *1e-6 ,label ="$H_2O$: 50th percentile")
# #axs[0][0].plot(ea_CCAT_annual_95[0:16],act_freq_shift_CCAT_annual_95 *1e-6,label ="$H_2O$: 95th percentile")
# axs[0][0].legend()

# axs[0][1].set_title("Dec, Jan, Feb")
# axs[0][1].plot(ea_CCAT[0:16],act_freq_shift_CCAT_DJF_5 *1e-6 ,label ="$H_2O$: 5th percentile")
# axs[0][1].plot(ea_CCAT[0:16],act_freq_shift_CCAT_DJF_50 *1e-6 ,label ="$H_2O$: 50th percentile")
# #axs[0][1].plot(ea_CCAT_DJF_95[0:16],act_freq_shift_CCAT_DJF_95 *1e-6 ,label ="$H_2O$: 95th percentile")
# axs[0][1].legend()

# axs[0][2].set_title("Jan, Feb, Mar")
# axs[0][2].plot(ea_CCAT[0:16],act_freq_shift_CCAT_JFM_5 *1e-6 ,label ="$H_2O$: 5th percentile")
# axs[0][2].plot(ea_CCAT[0:16],act_freq_shift_CCAT_JFM_50 *1e-6,label ="$H_2O$: 50th percentile")
# #axs[0][2].plot(ea_CCAT_JFM_95[0:16],act_freq_shift_CCAT_JFM_95 *1e-6 ,label ="$H_2O$: 95th percentile")
# axs[0][2].legend()

# axs[1][0].set_title("Mar, Apr, May")
# axs[1][0].plot(ea_CCAT[0:16],act_freq_shift_CCAT_MAM_5 *1e-6,label ="$H_2O$: 5th percentile")
# axs[1][0].plot(ea_CCAT[0:16],act_freq_shift_CCAT_MAM_50 *1e-6,label ="$H_2O$: 50th percentile")
# #axs[1][0].plot(ea_CCAT_MAM_95[0:16],act_freq_shift_CCAT_MAM_95 *1e-6 ,label ="$H_2O$: 95th percentile")
# axs[1][0].legend()

# axs[1][1].set_title("Jun, Jul, Aug")
# axs[1][1].plot(ea_CCAT[0:16],act_freq_shift_CCAT_JJA_5 *1e-6 ,label ="$H_2O$: 5th percentile")
# axs[1][1].plot(ea_CCAT[0:16],act_freq_shift_CCAT_JJA_50 *1e-6 ,label ="$H_2O$: 50th percentile")
# #axs[1][1].plot(ea_CCAT_JJA_95[0:16],act_freq_shift_CCAT_JJA_95 *1e-6,label ="$H_2O$: 95th percentile")
# axs[1][1].legend()

# axs[1][2].set_title("Sep, Oct, Nov")
# axs[1][2].plot(ea_CCAT[0:16],act_freq_shift_CCAT_SON_5 *1e-6 ,label ="$H_2O$: 5th percentile")
# axs[1][2].plot(ea_CCAT[0:16],act_freq_shift_CCAT_SON_50 *1e-6,label ="$H_2O$: 50th percentile")
# #axs[1][2].plot(ea_CCAT_SON_95[0:16],act_freq_shift_CCAT_SON_95 *1e-6,label ="$H_2O$: 95th percentile")
# axs[1][2].legend()

# # plt.xlabel("Elevation Angle (dgrees)",size=12)
# # plt.ylabel("Loading act_freq_shifter (pW) ",size=12)

# fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
# fig.text(0.07, 0.5, ' Actual frequency shift (MHz)', va='center', rotation='vertical',size=14)


# plt.savefig("250ghz_outputs/Site Files : 250 GHz Actual detector frequency shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 43 GHz)_V1.jpg",dpi="figure")

# plt.show()

# %%
# ## plotting the freqeuncy shifts

# fig, axs = plt.subplots(2,3,sharex=True,sharey=True,figsize=(16,7))
# fig.suptitle("Site Files : 250 GHz Actual detector frequency shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 43 GHz)",size=13)

# axs[0][0].set_title("Annual")
# #axs[0][0].plot(ea_CCAT[0:16],act_freq_shift_CCAT_annual_5 *1e-6 ,label ="$H_2O$: 5th percentile")
# axs[0][0].plot(ea_CCAT[0:16],act_freq_shift_CCAT_annual_50 *1e-6 ,label ="$H_2O$: 50th percentile")
# #axs[0][0].plot(ea_CCAT_annual_95[0:16],act_freq_shift_CCAT_annual_95 *1e-6,label ="$H_2O$: 95th percentile")
# axs[0][0].legend()

# axs[0][1].set_title("Dec, Jan, Feb")
# #axs[0][1].plot(ea_CCAT[0:16],act_freq_shift_CCAT_DJF_5 *1e-6 ,label ="$H_2O$: 5th percentile")
# axs[0][1].plot(ea_CCAT[0:16],act_freq_shift_CCAT_DJF_50 *1e-6 ,label ="$H_2O$: 50th percentile")
# #axs[0][1].plot(ea_CCAT_DJF_95[0:16],act_freq_shift_CCAT_DJF_95 *1e-6 ,label ="$H_2O$: 95th percentile")
# axs[0][1].legend()

# axs[0][2].set_title("Jan, Feb, Mar")
# #axs[0][2].plot(ea_CCAT[0:16],act_freq_shift_CCAT_JFM_5 *1e-6 ,label ="$H_2O$: 5th percentile")
# axs[0][2].plot(ea_CCAT[0:16],act_freq_shift_CCAT_JFM_50 *1e-6,label ="$H_2O$: 50th percentile")
# #axs[0][2].plot(ea_CCAT_JFM_95[0:16],act_freq_shift_CCAT_JFM_95 *1e-6 ,label ="$H_2O$: 95th percentile")
# axs[0][2].legend()

# axs[1][0].set_title("Mar, Apr, May")
# #axs[1][0].plot(ea_CCAT[0:16],act_freq_shift_CCAT_MAM_5 *1e-6,label ="$H_2O$: 5th percentile")
# axs[1][0].plot(ea_CCAT[0:16],act_freq_shift_CCAT_MAM_50 *1e-6,label ="$H_2O$: 50th percentile")
# #axs[1][0].plot(ea_CCAT_MAM_95[0:16],act_freq_shift_CCAT_MAM_95 *1e-6 ,label ="$H_2O$: 95th percentile")
# axs[1][0].legend()

# axs[1][1].set_title("Jun, Jul, Aug")
# #axs[1][1].plot(ea_CCAT[0:16],act_freq_shift_CCAT_JJA_5 *1e-6 ,label ="$H_2O$: 5th percentile")
# axs[1][1].plot(ea_CCAT[0:16],act_freq_shift_CCAT_JJA_50 *1e-6 ,label ="$H_2O$: 50th percentile")
# #axs[1][1].plot(ea_CCAT_JJA_95[0:16],act_freq_shift_CCAT_JJA_95 *1e-6,label ="$H_2O$: 95th percentile")
# axs[1][1].legend()

# axs[1][2].set_title("Sep, Oct, Nov")
# #axs[1][2].plot(ea_CCAT[0:16],act_freq_shift_CCAT_SON_5 *1e-6 ,label ="$H_2O$: 5th percentile")
# axs[1][2].plot(ea_CCAT[0:16],act_freq_shift_CCAT_SON_50 *1e-6,label ="$H_2O$: 50th percentile")
# #axs[1][2].plot(ea_CCAT_SON_95[0:16],act_freq_shift_CCAT_SON_95 *1e-6,label ="$H_2O$: 95th percentile")
# axs[1][2].legend()

# # plt.xlabel("Elevation Angle (dgrees)",size=12)
# # plt.ylabel("Loading act_freq_shifter (pW) ",size=12)

# fig.text(0.5, 0.04, 'Elevation Angle (degrees)', ha='center',size=15)
# fig.text(0.07, 0.5, ' Actual frequency shift (MHz)', va='center', rotation='vertical',size=14)


# plt.savefig("250ghz_outputs/Site Files 50th : 250 GHz Actual detector frequency shift vs Elevation Angle (Alt= 5.6 Km| $\eta_{optical}=30\% $| BW= 43 GHz)_V1.jpg",dpi="figure")

# plt.show()
